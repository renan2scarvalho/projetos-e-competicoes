# %%
! pip install pandas==0.25
# Out:
# Collecting pandas==0.25
#   Downloading https://files.pythonhosted.org/packages/1d/9a/7eb9952f4b4d73fbd75ad1d5d6112f407e695957444cb695cbb3cdab918a/pandas-0.25.0-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
#      |████████████████████████████████| 10.5MB 4.7MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas==0.25) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas==0.25) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas==0.25) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas==0.25) (1.15.0)
# ERROR: google-colab 1.0.0 has requirement pandas~=1.1.0; python_version >= "3.0", but you'll have pandas 0.25.0 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement pandas>=1.0.4, but you'll have pandas 0.25.0 which is incompatible.
# Installing collected packages: pandas
#   Found existing installation: pandas 1.1.4
#     Uninstalling pandas-1.1.4:
#       Successfully uninstalled pandas-1.1.4
# Successfully installed pandas-0.25.0

# %%
import pkg_resources
pkg_resources.require("Pandas==0.25") # for panads_profiling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wn

# %matplotlib inline
wn.filterwarnings('ignore')

# %%
pd.__version__
# Out:
# '0.25.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Competições/Modeling Earthquake Damage/train_values.csv')
val = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Competições/Modeling Earthquake Damage/test_values.csv')
train_labels = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Competições/Modeling Earthquake Damage/train_labels.csv')

# %%
train = train.merge(train_labels)

# %%
train.shape, val.shape
# Out:
# ((260601, 40), (86868, 39))

# %%
train.head()
# Out:
#    building_id  geo_level_1_id  ...  has_secondary_use_other  damage_grade
# 0       802906               6  ...                        0             3
# 1        28830               8  ...                        0             2
# 2        94947              21  ...                        0             3
# 3       590882              22  ...                        0             2
# 4       201944              11  ...                        0             3
#
# [5 rows x 40 columns]

# %%
train = train.drop(['building_id'], axis=1)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Report

# %%
from pandas_profiling import ProfileReport

report = ProfileReport(train)

# %%
report
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>39 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>260601 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>79.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>320.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>22 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_geo_level_1_id"><code>geo_level_1_id</code></a> has 4011 / 1.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_age"><code>age</code></a> has 26041 / 10.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_count_families"><code>count_families</code></a> has 20862 / 8.0% zeros <span class="label label-info">Zeros</span></li><li>Dataset has 12319 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_geo_level_1_id">geo_level_1_id<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>31</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>

# %% [markdown]
# ## Imbalance

# %%
numeric = train.select_dtypes('number')

# %%
binary = numeric.drop(['geo_level_1_id',
                      'geo_level_2_id',
                      'geo_level_3_id',
                      'count_floors_pre_eq',
                      'age',
                      'area_percentage',
                      'height_percentage',
                      'count_families',
                      'damage_grade'], axis=1)

# %%
# check imbalance
# has_superstructure_mud_mortar_stone
# has_superstructure_timber
# has_secondary_use
labels = binary.columns.tolist()
for label in labels:
  print(label,'     ',binary[label].value_counts().tolist()[1]/binary[label].value_counts().tolist()[0])
# Out:
# has_superstructure_adobe_mud       0.09726736842105263
# has_superstructure_mud_mortar_stone       0.312448063819179
# has_superstructure_stone_flag       0.03555278278906753
# has_superstructure_cement_mortar_stone       0.018573455436605185
# has_superstructure_mud_mortar_brick       0.0731386921429748
# has_superstructure_cement_mortar_brick       0.08139476982065348
# has_superstructure_timber       0.3422593754345844
# has_superstructure_bamboo       0.09290953545232274
# has_superstructure_rc_non_engineered       0.044484613349792784
# has_superstructure_rc_engineered       0.016115070886036465
# has_superstructure_other       0.015212547137470004
# has_secondary_use       0.12597377346669836
# has_secondary_use_agriculture       0.068807828597677
# has_secondary_use_hotel       0.03479617849569962
# has_secondary_use_rental       0.008166660218963983
# has_secondary_use_institution       0.0009410192198374533
# has_secondary_use_school       0.00036083483361291636
# has_secondary_use_industry       0.00107174960241547
# has_secondary_use_health_post       0.00018806226780066935
# has_secondary_use_gov_office       0.00014583805068256047
# has_secondary_use_use_police       8.826531787027301e-05
# has_secondary_use_other       0.005145274948219403

# %%
nominal = train.select_dtypes('object')

# %%
# check imbalance
# land_surface_condition
# roof_type
# ground_floor_type
# other_floor_type
labels = nominal.columns.tolist()
for label in labels:
  print(label,'     ',nominal[label].value_counts().tolist()[1]/nominal[label].value_counts().tolist()[0])
# Out:
# land_surface_condition       0.1639070479846095
# foundation_type       0.06897023668315115
# roof_type       0.33677163890134654
# ground_floor_type       0.11867721914521108
# other_floor_type       0.26287194007816944
# position       0.21226186352615173
# plan_configuration       0.02276144470392527
# legal_ownership_status       0.021965497591048024

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Feature Importance

# %%
X = train.drop(['damage_grade'], axis=1)
y = train['damage_grade']

# %%
cat_labels = X.select_dtypes('object').columns.tolist()

# %%
X = pd.get_dummies(X, columns=cat_labels)

# %%
X.shape, y.shape
# Out:
# ((260601, 68), (260601,))

# %% [markdown]
# #### Wrapper Methods

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf_rf = RandomForestClassifier(random_state=42).fit(X,y)

# %%
RF_features = pd.DataFrame(clf_rf.feature_importances_, index=X.columns.tolist(), 
                         columns=['RF']).sort_values(by=['RF'], ascending=False).head(30).index.tolist()

# %%
RF_features
# Out:
# ['geo_level_3_id',
#  'geo_level_2_id',
#  'geo_level_1_id',
#  'age',
#  'area_percentage',
#  'height_percentage',
#  'count_families',
#  'count_floors_pre_eq',
#  'foundation_type_r',
#  'has_superstructure_mud_mortar_stone',
#  'has_superstructure_timber',
#  'ground_floor_type_v',
#  'land_surface_condition_t',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f',
#  'land_surface_condition_n',
#  'position_s',
#  'has_superstructure_adobe_mud',
#  'other_floor_type_q',
#  'roof_type_n',
#  'has_secondary_use',
#  'position_t',
#  'roof_type_q',
#  'has_superstructure_bamboo',
#  'foundation_type_i',
#  'has_superstructure_mud_mortar_brick',
#  'other_floor_type_x',
#  'ground_floor_type_x',
#  'has_superstructure_stone_flag',
#  'roof_type_x']

# %% [markdown]
# ##### Extra Tree

# %%
from sklearn.tree import ExtraTreeClassifier

# %%
clf_et = ExtraTreeClassifier().fit(X,y)

# %%
ET_features = pd.DataFrame(clf_et.feature_importances_, index=X.columns.tolist(), 
                         columns=['ET']).sort_values(by=['ET'], ascending=False).head(30).index.tolist()

# %%
ET_features
# Out:
# ['age',
#  'area_percentage',
#  'geo_level_3_id',
#  'geo_level_1_id',
#  'geo_level_2_id',
#  'height_percentage',
#  'count_families',
#  'foundation_type_i',
#  'count_floors_pre_eq',
#  'has_superstructure_timber',
#  'has_superstructure_mud_mortar_stone',
#  'foundation_type_r',
#  'has_superstructure_adobe_mud',
#  'roof_type_n',
#  'has_superstructure_mud_mortar_brick',
#  'land_surface_condition_t',
#  'has_superstructure_bamboo',
#  'ground_floor_type_f',
#  'foundation_type_u',
#  'position_t',
#  'roof_type_q',
#  'other_floor_type_q',
#  'has_superstructure_stone_flag',
#  'land_surface_condition_n',
#  'ground_floor_type_x',
#  'other_floor_type_x',
#  'position_s',
#  'has_superstructure_cement_mortar_brick',
#  'has_superstructure_rc_non_engineered',
#  'has_superstructure_other']

# %% [markdown]
# ##### Select Predictors

# %%
wrapper_features = []
for el in RF_features:
  if el in ET_features:
    wrapper_features.append(el)

# %%
print(len(wrapper_features))
wrapper_features
# Out:
# 27
# ['geo_level_3_id',
#  'geo_level_2_id',
#  'geo_level_1_id',
#  'age',
#  'area_percentage',
#  'height_percentage',
#  'count_families',
#  'count_floors_pre_eq',
#  'foundation_type_r',
#  'has_superstructure_mud_mortar_stone',
#  'has_superstructure_timber',
#  'land_surface_condition_t',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f',
#  'land_surface_condition_n',
#  'position_s',
#  'has_superstructure_adobe_mud',
#  'other_floor_type_q',
#  'roof_type_n',
#  'position_t',
#  'roof_type_q',
#  'has_superstructure_bamboo',
#  'foundation_type_i',
#  'has_superstructure_mud_mortar_brick',
#  'other_floor_type_x',
#  'ground_floor_type_x',
#  'has_superstructure_stone_flag']

# %% [markdown]
# #### Filter Methods

# %%
filter = train.copy()
filter = pd.get_dummies(filter, columns=cat_labels)

# %%
train.shape, filter.shape
# Out:
# ((260601, 39), (260601, 69))

# %% [markdown]
# ##### Quantitative

# %%
quantitative = filter[['geo_level_1_id',
                      'geo_level_2_id',
                      'geo_level_3_id',
                      'count_floors_pre_eq',
                      'age',
                      'area_percentage',
                      'height_percentage',
                      'count_families',
                      'damage_grade']]

# %%
# spearm correlation heatmap
fig, ax=plt.subplots(figsize=(8,4))
sns.heatmap(quantitative.select_dtypes('number').corr(method='spearman').round(2), annot=True, cmap='YlGnBu', ax=ax);

# %%
from scipy.stats import spearmanr

# %% [markdown]
# ###### count_floors_pre_eq ; height_percentage

# %%
spearmanr(train['count_floors_pre_eq'], train['height_percentage']) # high correlation
# Out:
# SpearmanrResult(correlation=0.7554792083087991, pvalue=0.0)

# %%
spearmanr(train['count_floors_pre_eq'], train['damage_grade']) # use count_floors_pre_eq
# Out:
# SpearmanrResult(correlation=0.14169833217151567, pvalue=0.0)

# %%
spearmanr(train['height_percentage'], train['damage_grade'])
# Out:
# SpearmanrResult(correlation=0.08028182614939544, pvalue=0.0)

# %% [markdown]
# ###### Association

# %%
quantitative_labels = quantitative.columns.tolist()
quantitative_labels.remove('height_percentage')
quantitative_labels.remove('damage_grade')

# %%
quantitative_association = []
for label in quantitative_labels:
  corr, _ = spearmanr(filter[label], filter['damage_grade'])
  if corr > 0.2:
    quantitative_association.append(label)

# %%
quantitative_association
# Out:
# []

# %% [markdown]
# ##### Nominal

# %%
from scipy.stats import chi2_contingency

# %%
def cramers_v(var1, var2):
  confusion_matrix = np.array(pd.crosstab(var1, var2, rownames=None, colnames=None))
  chi2 = chi2_contingency(confusion_matrix)[0]
  n = confusion_matrix.sum()
  phi2 = chi2 / n
  r, k = confusion_matrix.shape
  phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
  rcorr = r - ((r-1)**2)/(n-1)
  kcorr = k - ((k-1)**2)/(n-1)
  return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# %%
quantitative_labels = quantitative.columns.tolist()
binary_labels = filter.drop(quantitative_labels, axis=1).columns.tolist()

# %%
binary_corr = []
for i in range(len(binary_labels)):
  for j in range(len(binary_labels)):
    try:
      assert binary_labels[i] != binary_labels[j]
      binary_corr.append([binary_labels[i], 
                       binary_labels[j], 
                       cramers_v(filter[binary_labels[i]], filter[binary_labels[j]])]
                      )
    except:
      pass

# %%
binary_association = pd.DataFrame(binary_corr, columns=['label1','label2','Cramer_V'])\
                                  .drop_duplicates(subset=['Cramer_V'])\
                                  .sort_values(by=['Cramer_V'], ascending=False)

# %% [markdown]
# ###### Strong association

# %%
label1 = binary_association.query('Cramer_V>=0.7')['label1'].tolist()
label2 = binary_association.query('Cramer_V>=0.7')['label2'].tolist()

strong_association = []
caution = []
for el1,el2 in zip(label1,label2):
  val1 = cramers_v(filter[el1], filter['damage_grade'])
  val2 = cramers_v(filter[el2], filter['damage_grade'])
  if val1 > 0.2:
    caution.append(el1)
  elif val2 > 0.2:
    caution.append(el2) 
  if val1 > val2:
    strong_association.append(el1)
  else:
    strong_association.append(el2)

strong_association = list(set(strong_association))
caution = list(set(caution))

# %%
strong_association
# Out:
# ['roof_type_n',
#  'land_surface_condition_t',
#  'position_t',
#  'roof_type_x',
#  'plan_configuration_d',
#  'legal_ownership_status_a',
#  'has_secondary_use']

# %%
caution
# Out:
# ['roof_type_x', 'foundation_type_i']

# %%
for el in caution:
  if el not in strong_association:
    strong_association.append(el)

# %%
strong_association
# Out:
# ['roof_type_n',
#  'land_surface_condition_t',
#  'position_t',
#  'roof_type_x',
#  'plan_configuration_d',
#  'legal_ownership_status_a',
#  'has_secondary_use',
#  'foundation_type_i']

# %% [markdown]
# ###### Moderate association

# %%
label1 = binary_association.query('0.3<=Cramer_V<0.7')['label1'].tolist()
label2 = binary_association.query('0.3<=Cramer_V<0.7')['label2'].tolist()

moderate_association = []
caution = []
for el1,el2 in zip(label1,label2):
  val1 = cramers_v(filter[el1], filter['damage_grade'])
  val2 = cramers_v(filter[el2], filter['damage_grade'])
  if val1 > 0.2: 
    caution.append(el1)
  elif val2 > 0.3:
    caution.append(el2)
  if val1 > val2:
    moderate_association.append(el1)
  else:
    moderate_association.append(el2)

moderate_association = list(set(moderate_association))
caution = list(set(caution))

# %%
moderate_association
# Out:
# ['foundation_type_r',
#  'ground_floor_type_v',
#  'other_floor_type_q',
#  'foundation_type_w',
#  'legal_ownership_status_v',
#  'has_superstructure_adobe_mud',
#  'land_surface_condition_t',
#  'has_secondary_use_hotel',
#  'foundation_type_i',
#  'position_j',
#  'other_floor_type_s',
#  'has_superstructure_mud_mortar_stone',
#  'roof_type_x',
#  'plan_configuration_u',
#  'has_superstructure_timber',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f']

# %%
caution
# Out:
# ['foundation_type_r',
#  'ground_floor_type_v',
#  'has_superstructure_rc_engineered',
#  'other_floor_type_q',
#  'ground_floor_type_f',
#  'foundation_type_i',
#  'has_superstructure_mud_mortar_stone',
#  'roof_type_x',
#  'has_superstructure_cement_mortar_brick']

# %%
for el in caution:
  if el not in moderate_association:
    moderate_association.append(el)

# %%
moderate_association
# Out:
# ['foundation_type_r',
#  'ground_floor_type_v',
#  'other_floor_type_q',
#  'foundation_type_w',
#  'legal_ownership_status_v',
#  'has_superstructure_adobe_mud',
#  'land_surface_condition_t',
#  'has_secondary_use_hotel',
#  'foundation_type_i',
#  'position_j',
#  'other_floor_type_s',
#  'has_superstructure_mud_mortar_stone',
#  'roof_type_x',
#  'plan_configuration_u',
#  'has_superstructure_timber',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f',
#  'has_superstructure_rc_engineered']

# %% [markdown]
# ###### Join

# %%
nominal_association = strong_association
for el in moderate_association:
  if el not in nominal_association:
    nominal_association.append(el)

# %%
nominal_association
# Out:
# ['roof_type_n',
#  'land_surface_condition_t',
#  'position_t',
#  'roof_type_x',
#  'plan_configuration_d',
#  'legal_ownership_status_a',
#  'has_secondary_use',
#  'foundation_type_i',
#  'foundation_type_r',
#  'ground_floor_type_v',
#  'other_floor_type_q',
#  'foundation_type_w',
#  'legal_ownership_status_v',
#  'has_superstructure_adobe_mud',
#  'has_secondary_use_hotel',
#  'position_j',
#  'other_floor_type_s',
#  'has_superstructure_mud_mortar_stone',
#  'plan_configuration_u',
#  'has_superstructure_timber',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f',
#  'has_superstructure_rc_engineered']

# %% [markdown]
# ##### Quantitative / Binary

# %%
from scipy.stats import pointbiserialr

# %%
biserial = []
for i in range(len(binary_labels)):
  for j in range(len(quantitative_labels)):
    value, _ = pointbiserialr(filter[binary_labels[i]], filter[quantitative_labels[j]])
    biserial.append(
                    [binary_labels[i], quantitative_labels[j], value]
                    )

# %%
biserial_association = pd.DataFrame(biserial, columns=['label1','label2','Point_Biserial'])\
                                    .drop_duplicates(subset=['Point_Biserial'])\
                                    .sort_values(by=['Point_Biserial'], ascending=False)

# %%
label1 = biserial_association.query('Point_Biserial<=-0.7 or Point_Biserial>=0.7')['label1'].tolist()
label2 = biserial_association.query('Point_Biserial<=-0.7 or Point_Biserial>=0.7')['label2'].tolist()

quantitative_binary_association = label1
for el in label2:
  if el not in quantitative_binary_association:
    quantitative_binary_association.append(el)

# %%
quantitative_binary_association
# Out:
# []

# %% [markdown]
# ##### Association with response variable

# %%
filter_features = quantitative_association

for el in nominal_association:
  if el not in filter_features:
    filter_features.append(el)

for el in quantitative_binary_association:
  if el not in filter_features:
    filter_features.append(el)

# %%
print(len(filter_features))
filter_features
# Out:
# 23
# ['roof_type_n',
#  'land_surface_condition_t',
#  'position_t',
#  'roof_type_x',
#  'plan_configuration_d',
#  'legal_ownership_status_a',
#  'has_secondary_use',
#  'foundation_type_i',
#  'foundation_type_r',
#  'ground_floor_type_v',
#  'other_floor_type_q',
#  'foundation_type_w',
#  'legal_ownership_status_v',
#  'has_superstructure_adobe_mud',
#  'has_secondary_use_hotel',
#  'position_j',
#  'other_floor_type_s',
#  'has_superstructure_mud_mortar_stone',
#  'plan_configuration_u',
#  'has_superstructure_timber',
#  'has_superstructure_cement_mortar_brick',
#  'ground_floor_type_f',
#  'has_superstructure_rc_engineered']

# %% [markdown]
# ### Select Predictors
#
# wrapper_features\
# filter_features

# %%
train_df = train.copy()
val_df = val.copy()

# %%
categorical_labels = train_df.select_dtypes('object').columns.tolist()

# %%
train_df = pd.get_dummies(train_df, columns = categorical_labels)
val_df = pd.get_dummies(val_df, columns=categorical_labels)

# %%
# predictors = wrapper_features

# for el in filter_features:
#   if el not in predictors:
#     predictors.append(el)

# %%
wrapper_features.append('damage_grade')

# %%
train_df = train_df[wrapper_features]

# %%
wrapper_features.remove('damage_grade')

# %%
val_df = val_df[wrapper_features]

# %% [markdown]
# ### Feature Transformation

# %%
train_df.head(3)
# Out:
#    geo_level_3_id  geo_level_2_id  ...  has_superstructure_stone_flag  damage_grade
# 0           12198             487  ...                              0             3
# 1            2812             900  ...                              0             2
# 2            8973             363  ...                              0             3
#
# [3 rows x 28 columns]

# %% [markdown]
# #### geo_level_1_id

# %%
from sklearn.cluster import KMeans

# %%
geo1 = np.array(train_df['geo_level_1_id']).reshape(-1,1)
association = []
clusters = np.arange(2,11)
for c in clusters:
  kmeans = KMeans(n_clusters=c, random_state=42).fit(geo1)
  ass, _ = spearmanr(train_df['damage_grade'], kmeans.labels_) 
  association.append([c,ass])

association # 3 or 5 clusters
# Out:
# [[2, -0.012919720573425855],
#  [3, 0.1675160166885989],
#  [4, -0.06638476450494157],
#  [5, -0.166109182139388],
#  [6, 0.08985218587150919],
#  [7, 0.02818666042759728],
#  [8, 9.114089694292648e-05],
#  [9, 0.022999168980235903],
#  [10, 0.026354635626087784]]

# %%
kmeans = KMeans(n_clusters=3, random_state=42).fit(geo1)
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([ 46549, 132347,  81705]))

# %%
train_df['geo1_kmeans'] = kmeans.labels_

# %%
geo1_validation = np.array(val_df['geo_level_1_id']).reshape(-1,1)
kmeans = KMeans(n_clusters=3, random_state=42).fit(geo1_validation)

# %%
val_df['geo1_kmeans'] = geo1_validation

# %% [markdown]
# # Model

# %%
X = train_df.drop(['damage_grade'], axis=1)
y = train_df[['damage_grade']]

# %%
X.shape, y.shape
# Out:
# ((260601, 28), (260601, 1))

# %% [markdown]
# ### Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((182420, 28), (78181, 28), (182420, 1), (78181, 1))

# %% [markdown]
# ### LightGBM [[1]](https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html)

# %% [markdown]
# #### Model

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
num_leaves = [10, 30, 50]
max_depth = [5, 10, 30, 50]
learning_rate = [0.5, 0.8, 1, 1.5]
n_estimators = [50, 100, 150]
subsample = [0.5, 0.8, 1]
min_child_samples = [10, 50, 100]
min_child_weight = [0.001, 0.01, 0.1, 1]
reg_alpha = [0, 0.1, 1, 5]
reg_lambda = [0, 0.1, 1, 5]

param_distributions = dict(num_leaves=num_leaves, max_depth=max_depth, learning_rate=learning_rate, n_estimators=n_estimators,
                           subsample=subsample, min_child_samples=min_child_samples, min_child_weight=min_child_weight,
                           reg_alpha=reg_alpha, reg_lambda=reg_lambda)

clf = LGBMClassifier(objective='multiclass', random_state=42, n_jobs=-1)

search = RandomizedSearchCV(estimator=clf, param_distributions=param_distributions, 
                            cv=3, scoring='accuracy', refit=True, verbose=True, random_state=42).fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  2.3min finished

# %%
search.best_params_
# Out:
# {'learning_rate': 0.5,
#  'max_depth': 50,
#  'min_child_samples': 10,
#  'min_child_weight': 0.001,
#  'n_estimators': 100,
#  'num_leaves': 50,
#  'reg_alpha': 0,
#  'reg_lambda': 0.1,
#  'subsample': 0.5}

# %%
lgbm = LGBMClassifier(objective='multiclass', random_state=42, 
                     learning_rate= 0.5,
                    max_depth= 5,
                    min_child_samples= 10,
                    min_child_weight= 0.01,
                    n_estimators= 150,
                    num_leaves= 50,
                    reg_alpha= 5,
                    reg_lambda= 1,
                    subsample= 1)

# %%
lgbm.fit(x_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.5, max_depth=5,
#                min_child_samples=10, min_child_weight=0.01, min_split_gain=0.0,
#                n_estimators=150, n_jobs=-1, num_leaves=50,
#                objective='multiclass', random_state=42, reg_alpha=5,
#                reg_lambda=1, silent=True, subsample=1, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
y_pred = lgbm.predict(x_test)

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import confusion_matrix, f1_score, plot_confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
confusion_matrix(y_test, y_pred, labels=[1,2,3])
# Out:
# array([[ 3664,  3851,    86],
#        [ 1496, 37744,  5174],
#        [  119, 10176, 15871]])

# %%
plot_confusion_matrix(lgbm, x_test, y_test, normalize='true');

# %%
f1_score(y_test, y_pred, average='micro')
# Out:
# 0.7326460393190163

# %%
cross_val_score(lgbm, x_train, y_train, cv=3).mean()
# Out:
# 0.72652670581328

# %% [markdown]
# - RF_features -> accuracy: 0.7350379248154921
# - predictors -> accuracy: 0.7295762397513461
# - filter_features -> accuracy: 0.5850782159348179

# %% [markdown]
# #### Explaination with SHAP

# %%
import shap

# %%
explainer = shap.TreeExplainer(lgbm)

# %%
shap_values = explainer.shap_values(x_test.iloc[:1000,:])

# %%
shap.initjs()
shap.summary_plot(shap_values, x_test.iloc[:1000,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# SHAP calculates the probabilities on the log-odds space: $log(p) = log\frac{p}{(1-p)}$\
# The features in pink increase the log-odds probability, whereas the features in blue decrease it, in the proportion of each feature bar length.\
# The first two predictions are shown ahead:

# %%
# show first prediction
shap.initjs()
shap.force_plot(explainer.expected_value[0], shap_values[0][0,:], x_test.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iOY0WX45MKU6NML1ZIHRP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -3.692891380508437, "outValue": -5.184751928262335, "link": "identity", "featureNames": ["geo_level_3_id", "geo_level_2_id", "geo_level_1_id", "age", "area_percentage", "height_percentage", "count_families", "count_floors_pre_eq", "foundation_type_r", "has_superstructure_mud_mortar_stone", "has_superstructure_timber", "land_surface_condition_t", "has_superstructure_cement_mortar_brick", "ground_floor_type_f", "land_surface_condition_n", "position_s", "has_superstructure_adobe_mud", "other_floor_type_q", "roof_type_n", "position_t", "roof_type_q", "has_superstructure_bamboo", "foundation_type_i", "has_superstructure_mud_mortar_brick", "other_floor_type_x", "ground_floor_type_x", "has_superstructure_stone_flag", "geo1_kmeans"], "features": {"0": {"effect": -0.014939118833893294, "value": 11128.0}, "1": {"effect": -0.3934866455543645, "value": 1224.0}, "2": {"effect": -0.6449645445807315, "value": 10.0}, "3": {"effect": -0.21841161272056014, "value": 20.0}, "4": {"effect": -0.05654169867714838, "value": 7.0}, "5": {"effect": 0.12036243317531524, "value": 3.0}, "6": {"effect": -0.04098983583840294, "value": 1.0}, "7": {"effect": 0.06061422385124045, "value": 1.0}, "8": {"effect": -0.14529954215632648, "value": 1.0}, "9": {"effect": -0.18374717897116513, "value": 1.0}, "10": {"effect": -0.01923415780974843, "value": 0.0}, "11": {"effect": 0.03208459543551406, "value": 1.0}, "12": {"effect": -0.0048408013721099406, "value": 0.0}, "13": {"effect": -0.07651990206489934, "value": 1.0}, "14": {"effect": -0.021715380642018046, "value": 0.0}, "15": {"effect": -0.016394242131065363, "value": 1.0}, "16": {"effect": 0.03218983179025339, "value": 0.0}, "17": {"effect": 0.03913824353104387, "value": 0.0}, "18": {"effect": -0.06379902975269529, "value": 1.0}, "19": {"effect": 0.028977284136048203, "value": 0.0}, "20": {"effect": 0.042099699592611645, "value": 0.0}, "21": {"effect": -0.01205942853676053, "value": 0.0}, "22": {"effect": -0.0048018477880338575, "value": 0.0}, "23": {"effect": -4.013834670495389e-05, "value": 0.0}, "24": {"effect": 0.04629738268057647, "value": 0.0}, "25": {"effect": -0.007346852910867522, "value": 0.0}, "26": {"effect": 0.039942501893965525, "value": 0.0}, "27": {"effect": -0.008434785152970936, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOY0WX45MKU6NML1ZIHRP')
#   );
# </script>

# %%
# show second prediction
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1][0,:], x_test.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iJHGX9VO5M7NA9EI239LQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.4702469979620574, "outValue": -0.9985580740057873, "link": "identity", "featureNames": ["geo_level_3_id", "geo_level_2_id", "geo_level_1_id", "age", "area_percentage", "height_percentage", "count_families", "count_floors_pre_eq", "foundation_type_r", "has_superstructure_mud_mortar_stone", "has_superstructure_timber", "land_surface_condition_t", "has_superstructure_cement_mortar_brick", "ground_floor_type_f", "land_surface_condition_n", "position_s", "has_superstructure_adobe_mud", "other_floor_type_q", "roof_type_n", "position_t", "roof_type_q", "has_superstructure_bamboo", "foundation_type_i", "has_superstructure_mud_mortar_brick", "other_floor_type_x", "ground_floor_type_x", "has_superstructure_stone_flag", "geo1_kmeans"], "features": {"0": {"effect": -0.14881031570630265, "value": 11128.0}, "1": {"effect": -0.016482447712078758, "value": 1224.0}, "2": {"effect": -0.018167111152749722, "value": 10.0}, "3": {"effect": 0.011840153788314592, "value": 20.0}, "4": {"effect": 0.023262187624706502, "value": 7.0}, "5": {"effect": -0.01950730093759952, "value": 3.0}, "6": {"effect": -0.007741887927577121, "value": 1.0}, "7": {"effect": -0.12567083584268982, "value": 1.0}, "8": {"effect": -0.0011650017134908742, "value": 1.0}, "9": {"effect": 0.003088415420504977, "value": 1.0}, "10": {"effect": -0.011489640006811562, "value": 0.0}, "11": {"effect": 0.00032930876769564414, "value": 1.0}, "12": {"effect": -0.045085726658627076, "value": 0.0}, "13": {"effect": -0.010878940536582804, "value": 1.0}, "14": {"effect": -0.0023510079790441916, "value": 0.0}, "15": {"effect": -0.02988277262352877, "value": 1.0}, "16": {"effect": -0.013580990544340686, "value": 0.0}, "17": {"effect": -0.07684170288559812, "value": 0.0}, "18": {"effect": -0.001908303325479267, "value": 1.0}, "19": {"effect": 0.007702554820203225, "value": 0.0}, "20": {"effect": -0.011572017531325461, "value": 0.0}, "21": {"effect": 0.0006659364621118654, "value": 0.0}, "22": {"effect": 0.0023013838399148223, "value": 0.0}, "23": {"effect": -0.032178525778526645, "value": 0.0}, "24": {"effect": 0.0011352677829238368, "value": 0.0}, "25": {"effect": 0.0016383939765820402, "value": 0.0}, "26": {"effect": 0.0016645085407300671, "value": 0.0}, "27": {"effect": -0.008624658205064495, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJHGX9VO5M7NA9EI239LQ')
#   );
# </script>

# %% [markdown]
# ### XGBoost [[1]](https://machinelearningmastery.com/stochastic-gradient-boosting-xgboost-scikit-learn-python/), [[2]](https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/), [[3]](https://github.com/ernestng11/touchpoint-prediction/blob/master/model-building.ipynb), [[4]](https://xgboost.readthedocs.io/en/latest/python/python_api.html)

# %%
import xgboost
from xgboost.sklearn import XGBClassifier

# %%
xgb = XGBClassifier(learning_rate=0.1,
                    n_estimators=1000, 
                    max_depth=5,
                    min_child_weight=1,
                    gamma=0,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    objective='multi:softmax',
                    nthread=4,
                    num_class=3,
                    seed=42)

# %%
xgb.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        eval_metric = ['merror','mlogloss'],
        early_stopping_rounds=500,
        verbose=True)
# Out:
# [0]	validation_0-merror:0.344781	validation_0-mlogloss:1.05329	validation_1-merror:0.346504	validation_1-mlogloss:1.05359
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 500 rounds.
# [1]	validation_0-merror:0.344266	validation_0-mlogloss:1.01815	validation_1-merror:0.346721	validation_1-mlogloss:1.01866
# [2]	validation_0-merror:0.344326	validation_0-mlogloss:0.983838	validation_1-merror:0.346504	validation_1-mlogloss:0.984374
# [3]	validation_0-merror:0.343997	validation_0-mlogloss:0.958109	validation_1-merror:0.346401	validation_1-mlogloss:0.958783
# [4]	validation_0-merror:0.342813	validation_0-mlogloss:0.931321	validation_1-merror:0.34525	validation_1-mlogloss:0.932097
# [5]	validation_0-merror:0.343115	validation_0-mlogloss:0.908253	validation_1-merror:0.345199	validation_1-mlogloss:0.909047
# [6]	validation_0-merror:0.341931	validation_0-mlogloss:0.887254	validation_1-merror:0.344534	validation_1-mlogloss:0.888121
# [7]	validation_0-merror:0.341843	validation_0-mlogloss:0.870044	validation_1-merror:0.34438	validation_1-mlogloss:0.871063
# [8]	validation_0-merror:0.341662	validation_0-mlogloss:0.855573	validation_1-merror:0.343536	validation_1-mlogloss:0.856691
# [9]	validation_0-merror:0.340851	validation_0-mlogloss:0.841264	validation_1-merror:0.343165	validation_1-mlogloss:0.842522
# [10]	validation_0-merror:0.339601	validation_0-mlogloss:0.828158	validation_1-merror:0.341925	validation_1-mlogloss:0.82948
# [11]	validation_0-merror:0.33891	validation_0-mlogloss:0.817	validation_1-merror:0.341259	validation_1-mlogloss:0.818406
# [12]	validation_0-merror:0.338022	validation_0-mlogloss:0.807209	validation_1-merror:0.340786	validation_1-mlogloss:0.808687
# [13]	validation_0-merror:0.33663	validation_0-mlogloss:0.797827	validation_1-merror:0.339584	validation_1-mlogloss:0.799413
# [14]	validation_0-merror:0.336493	validation_0-mlogloss:0.790455	validation_1-merror:0.339354	validation_1-mlogloss:0.792091
# [15]	validation_0-merror:0.335742	validation_0-mlogloss:0.783289	validation_1-merror:0.338599	validation_1-mlogloss:0.784929
# [16]	validation_0-merror:0.333571	validation_0-mlogloss:0.776625	validation_1-merror:0.336463	validation_1-mlogloss:0.778343
# [17]	validation_0-merror:0.332491	validation_0-mlogloss:0.770719	validation_1-merror:0.335197	validation_1-mlogloss:0.772489
# [18]	validation_0-merror:0.332359	validation_0-mlogloss:0.765502	validation_1-merror:0.334838	validation_1-mlogloss:0.767314
# [19]	validation_0-merror:0.331992	validation_0-mlogloss:0.760319	validation_1-merror:0.334352	validation_1-mlogloss:0.7622
# [20]	validation_0-merror:0.33089	validation_0-mlogloss:0.755698	validation_1-merror:0.3326	validation_1-mlogloss:0.757618
# [21]	validation_0-merror:0.329706	validation_0-mlogloss:0.751561	validation_1-merror:0.331155	validation_1-mlogloss:0.753522
# [22]	validation_0-merror:0.328983	validation_0-mlogloss:0.7474	validation_1-merror:0.330656	validation_1-mlogloss:0.7494
# [23]	validation_0-merror:0.328073	validation_0-mlogloss:0.743507	validation_1-merror:0.32953	validation_1-mlogloss:0.745535
# [24]	validation_0-merror:0.327946	validation_0-mlogloss:0.740397	validation_1-merror:0.329594	validation_1-mlogloss:0.742512
# [25]	validation_0-merror:0.327448	validation_0-mlogloss:0.737222	validation_1-merror:0.3293	validation_1-mlogloss:0.739378
# [26]	validation_0-merror:0.326889	validation_0-mlogloss:0.734228	validation_1-merror:0.32843	validation_1-mlogloss:0.736476
# [27]	validation_0-merror:0.325765	validation_0-mlogloss:0.731155	validation_1-merror:0.326742	validation_1-mlogloss:0.733467
# [28]	validation_0-merror:0.325167	validation_0-mlogloss:0.72877	validation_1-merror:0.326307	validation_1-mlogloss:0.731124
# [29]	validation_0-merror:0.324444	validation_0-mlogloss:0.725388	validation_1-merror:0.325616	validation_1-mlogloss:0.727767
# [30]	validation_0-merror:0.323934	validation_0-mlogloss:0.723007	validation_1-merror:0.325117	validation_1-mlogloss:0.725473
# [31]	validation_0-merror:0.323517	validation_0-mlogloss:0.720681	validation_1-merror:0.324746	validation_1-mlogloss:0.723235
# [32]	validation_0-merror:0.323676	validation_0-mlogloss:0.718415	validation_1-merror:0.324631	validation_1-mlogloss:0.721065
# [33]	validation_0-merror:0.32213	validation_0-mlogloss:0.716229	validation_1-merror:0.32357	validation_1-mlogloss:0.718927
# [34]	validation_0-merror:0.321527	validation_0-mlogloss:0.713984	validation_1-merror:0.323237	validation_1-mlogloss:0.716782
# [35]	validation_0-merror:0.320897	validation_0-mlogloss:0.712035	validation_1-merror:0.322687	validation_1-mlogloss:0.714881
# [36]	validation_0-merror:0.320321	validation_0-mlogloss:0.710433	validation_1-merror:0.322163	validation_1-mlogloss:0.713387
# [37]	validation_0-merror:0.320321	validation_0-mlogloss:0.708656	validation_1-merror:0.322175	validation_1-mlogloss:0.711688
# [38]	validation_0-merror:0.319669	validation_0-mlogloss:0.70716	validation_1-merror:0.321242	validation_1-mlogloss:0.710253
# [39]	validation_0-merror:0.319066	validation_0-mlogloss:0.70543	validation_1-merror:0.320653	validation_1-mlogloss:0.708598
# [40]	validation_0-merror:0.318249	validation_0-mlogloss:0.703564	validation_1-merror:0.319873	validation_1-mlogloss:0.706753
# [41]	validation_0-merror:0.318041	validation_0-mlogloss:0.702366	validation_1-merror:0.319592	validation_1-mlogloss:0.70564
# [42]	validation_0-merror:0.317465	validation_0-mlogloss:0.700972	validation_1-merror:0.318722	validation_1-mlogloss:0.70428
# [43]	validation_0-merror:0.317021	validation_0-mlogloss:0.699881	validation_1-merror:0.318479	validation_1-mlogloss:0.703279
# [44]	validation_0-merror:0.316807	validation_0-mlogloss:0.698324	validation_1-merror:0.318223	validation_1-mlogloss:0.701829
# [45]	validation_0-merror:0.316248	validation_0-mlogloss:0.69704	validation_1-merror:0.317456	validation_1-mlogloss:0.700622
# [46]	validation_0-merror:0.315963	validation_0-mlogloss:0.695993	validation_1-merror:0.317098	validation_1-mlogloss:0.69966
# [47]	validation_0-merror:0.315399	validation_0-mlogloss:0.694877	validation_1-merror:0.316624	validation_1-mlogloss:0.698613
# [48]	validation_0-merror:0.3153	validation_0-mlogloss:0.693839	validation_1-merror:0.316304	validation_1-mlogloss:0.697648
# [49]	validation_0-merror:0.315042	validation_0-mlogloss:0.692934	validation_1-merror:0.315742	validation_1-mlogloss:0.69684
# [50]	validation_0-merror:0.31468	validation_0-mlogloss:0.691926	validation_1-merror:0.315754	validation_1-mlogloss:0.695901
# [51]	validation_0-merror:0.314055	validation_0-mlogloss:0.690796	validation_1-merror:0.315038	validation_1-mlogloss:0.694836
# [52]	validation_0-merror:0.313754	validation_0-mlogloss:0.689815	validation_1-merror:0.314834	validation_1-mlogloss:0.693921
# [53]	validation_0-merror:0.313491	validation_0-mlogloss:0.688904	validation_1-merror:0.314424	validation_1-mlogloss:0.69311
# [54]	validation_0-merror:0.313217	validation_0-mlogloss:0.68818	validation_1-merror:0.313734	validation_1-mlogloss:0.692412
# [55]	validation_0-merror:0.313107	validation_0-mlogloss:0.687059	validation_1-merror:0.31381	validation_1-mlogloss:0.691372
# [56]	validation_0-merror:0.312789	validation_0-mlogloss:0.686343	validation_1-merror:0.313593	validation_1-mlogloss:0.69076
# [57]	validation_0-merror:0.312438	validation_0-mlogloss:0.685522	validation_1-merror:0.313184	validation_1-mlogloss:0.689972
# [58]	validation_0-merror:0.312411	validation_0-mlogloss:0.684868	validation_1-merror:0.313068	validation_1-mlogloss:0.689393
# [59]	validation_0-merror:0.312362	validation_0-mlogloss:0.684219	validation_1-merror:0.312979	validation_1-mlogloss:0.688845
# [60]	validation_0-merror:0.312022	validation_0-mlogloss:0.683494	validation_1-merror:0.312749	validation_1-mlogloss:0.688248
# [61]	validation_0-merror:0.311523	validation_0-mlogloss:0.682604	validation_1-merror:0.312595	validation_1-mlogloss:0.687427
# [62]	validation_0-merror:0.311177	validation_0-mlogloss:0.68168	validation_1-merror:0.312211	validation_1-mlogloss:0.686593
# [63]	validation_0-merror:0.311029	validation_0-mlogloss:0.6811	validation_1-merror:0.312071	validation_1-mlogloss:0.68609
# [64]	validation_0-merror:0.310761	validation_0-mlogloss:0.680483	validation_1-merror:0.311943	validation_1-mlogloss:0.685515
# [65]	validation_0-merror:0.310514	validation_0-mlogloss:0.67986	validation_1-merror:0.311572	validation_1-mlogloss:0.684971
# [66]	validation_0-merror:0.310174	validation_0-mlogloss:0.679114	validation_1-merror:0.311201	validation_1-mlogloss:0.684302
# [67]	validation_0-merror:0.309982	validation_0-mlogloss:0.678581	validation_1-merror:0.311252	validation_1-mlogloss:0.683827
# [68]	validation_0-merror:0.309643	validation_0-mlogloss:0.677912	validation_1-merror:0.311329	validation_1-mlogloss:0.683235
# [69]	validation_0-merror:0.30944	validation_0-mlogloss:0.677465	validation_1-merror:0.311009	validation_1-mlogloss:0.682829
# [70]	validation_0-merror:0.309237	validation_0-mlogloss:0.676811	validation_1-merror:0.310702	validation_1-mlogloss:0.682232
# [71]	validation_0-merror:0.308996	validation_0-mlogloss:0.676391	validation_1-merror:0.310677	validation_1-mlogloss:0.681898
# [72]	validation_0-merror:0.30876	validation_0-mlogloss:0.675898	validation_1-merror:0.310433	validation_1-mlogloss:0.681475
# [73]	validation_0-merror:0.308596	validation_0-mlogloss:0.675176	validation_1-merror:0.310088	validation_1-mlogloss:0.680862
# [74]	validation_0-merror:0.308453	validation_0-mlogloss:0.674587	validation_1-merror:0.310011	validation_1-mlogloss:0.680348
# [75]	validation_0-merror:0.307976	validation_0-mlogloss:0.674011	validation_1-merror:0.309321	validation_1-mlogloss:0.679896
# [76]	validation_0-merror:0.307812	validation_0-mlogloss:0.673633	validation_1-merror:0.309167	validation_1-mlogloss:0.679585
# [77]	validation_0-merror:0.307642	validation_0-mlogloss:0.6732	validation_1-merror:0.30909	validation_1-mlogloss:0.679256
# [78]	validation_0-merror:0.307231	validation_0-mlogloss:0.67248	validation_1-merror:0.308681	validation_1-mlogloss:0.678574
# [79]	validation_0-merror:0.306803	validation_0-mlogloss:0.671831	validation_1-merror:0.308528	validation_1-mlogloss:0.678016
# [80]	validation_0-merror:0.306589	validation_0-mlogloss:0.671283	validation_1-merror:0.308489	validation_1-mlogloss:0.677527
# [81]	validation_0-merror:0.306381	validation_0-mlogloss:0.670767	validation_1-merror:0.307875	validation_1-mlogloss:0.677076
# [82]	validation_0-merror:0.306107	validation_0-mlogloss:0.670272	validation_1-merror:0.307607	validation_1-mlogloss:0.676663
# [83]	validation_0-merror:0.305646	validation_0-mlogloss:0.669825	validation_1-merror:0.307453	validation_1-mlogloss:0.676301
# [84]	validation_0-merror:0.305235	validation_0-mlogloss:0.66916	validation_1-merror:0.307236	validation_1-mlogloss:0.675724
# [85]	validation_0-merror:0.304945	validation_0-mlogloss:0.668698	validation_1-merror:0.307133	validation_1-mlogloss:0.675317
# [86]	validation_0-merror:0.304632	validation_0-mlogloss:0.668102	validation_1-merror:0.307018	validation_1-mlogloss:0.674794
# [87]	validation_0-merror:0.304484	validation_0-mlogloss:0.66765	validation_1-merror:0.306647	validation_1-mlogloss:0.674416
# [88]	validation_0-merror:0.304133	validation_0-mlogloss:0.667124	validation_1-merror:0.306481	validation_1-mlogloss:0.673987
# [89]	validation_0-merror:0.303508	validation_0-mlogloss:0.666323	validation_1-merror:0.305918	validation_1-mlogloss:0.673281
# [90]	validation_0-merror:0.302938	validation_0-mlogloss:0.665705	validation_1-merror:0.305496	validation_1-mlogloss:0.672743
# [91]	validation_0-merror:0.302746	validation_0-mlogloss:0.665357	validation_1-merror:0.305496	validation_1-mlogloss:0.67246
# [92]	validation_0-merror:0.302763	validation_0-mlogloss:0.665015	validation_1-merror:0.305535	validation_1-mlogloss:0.672172
# [93]	validation_0-merror:0.30262	validation_0-mlogloss:0.664643	validation_1-merror:0.305483	validation_1-mlogloss:0.671858
# [94]	validation_0-merror:0.302368	validation_0-mlogloss:0.664188	validation_1-merror:0.305368	validation_1-mlogloss:0.671476
# [95]	validation_0-merror:0.301957	validation_0-mlogloss:0.663718	validation_1-merror:0.304997	validation_1-mlogloss:0.67109
# [96]	validation_0-merror:0.301721	validation_0-mlogloss:0.663249	validation_1-merror:0.304869	validation_1-mlogloss:0.670694
# [97]	validation_0-merror:0.30154	validation_0-mlogloss:0.66293	validation_1-merror:0.304601	validation_1-mlogloss:0.670425
# [98]	validation_0-merror:0.300872	validation_0-mlogloss:0.662375	validation_1-merror:0.303872	validation_1-mlogloss:0.669954
# [99]	validation_0-merror:0.300658	validation_0-mlogloss:0.661909	validation_1-merror:0.303744	validation_1-mlogloss:0.669616
# [100]	validation_0-merror:0.300477	validation_0-mlogloss:0.661508	validation_1-merror:0.303462	validation_1-mlogloss:0.669297
# [101]	validation_0-merror:0.300312	validation_0-mlogloss:0.661197	validation_1-merror:0.30336	validation_1-mlogloss:0.669082
# [102]	validation_0-merror:0.300247	validation_0-mlogloss:0.660951	validation_1-merror:0.303399	validation_1-mlogloss:0.668885
# [103]	validation_0-merror:0.299803	validation_0-mlogloss:0.66056	validation_1-merror:0.303322	validation_1-mlogloss:0.668556
# [104]	validation_0-merror:0.299682	validation_0-mlogloss:0.660198	validation_1-merror:0.303117	validation_1-mlogloss:0.668219
# [105]	validation_0-merror:0.299572	validation_0-mlogloss:0.65982	validation_1-merror:0.303028	validation_1-mlogloss:0.667913
# [106]	validation_0-merror:0.299331	validation_0-mlogloss:0.65945	validation_1-merror:0.302976	validation_1-mlogloss:0.667609
# [107]	validation_0-merror:0.299282	validation_0-mlogloss:0.659129	validation_1-merror:0.302836	validation_1-mlogloss:0.667316
# [108]	validation_0-merror:0.29915	validation_0-mlogloss:0.65875	validation_1-merror:0.302836	validation_1-mlogloss:0.666992
# [109]	validation_0-merror:0.298405	validation_0-mlogloss:0.65802	validation_1-merror:0.302299	validation_1-mlogloss:0.666338
# [110]	validation_0-merror:0.298081	validation_0-mlogloss:0.657555	validation_1-merror:0.301774	validation_1-mlogloss:0.665978
# [111]	validation_0-merror:0.297944	validation_0-mlogloss:0.657234	validation_1-merror:0.301736	validation_1-mlogloss:0.665706
# [112]	validation_0-merror:0.297456	validation_0-mlogloss:0.656733	validation_1-merror:0.301339	validation_1-mlogloss:0.665289
# [113]	validation_0-merror:0.297117	validation_0-mlogloss:0.656216	validation_1-merror:0.301211	validation_1-mlogloss:0.66487
# [114]	validation_0-merror:0.296831	validation_0-mlogloss:0.655611	validation_1-merror:0.300917	validation_1-mlogloss:0.664312
# [115]	validation_0-merror:0.296557	validation_0-mlogloss:0.655154	validation_1-merror:0.300636	validation_1-mlogloss:0.663925
# [116]	validation_0-merror:0.296228	validation_0-mlogloss:0.654734	validation_1-merror:0.300393	validation_1-mlogloss:0.663645
# [117]	validation_0-merror:0.295932	validation_0-mlogloss:0.654327	validation_1-merror:0.300329	validation_1-mlogloss:0.663334
# [118]	validation_0-merror:0.295439	validation_0-mlogloss:0.654022	validation_1-merror:0.299932	validation_1-mlogloss:0.663104
# [119]	validation_0-merror:0.295198	validation_0-mlogloss:0.65368	validation_1-merror:0.299804	validation_1-mlogloss:0.662839
# [120]	validation_0-merror:0.295088	validation_0-mlogloss:0.653291	validation_1-merror:0.299792	validation_1-mlogloss:0.662494
# [121]	validation_0-merror:0.295192	validation_0-mlogloss:0.652867	validation_1-merror:0.299651	validation_1-mlogloss:0.662133
# [122]	validation_0-merror:0.294496	validation_0-mlogloss:0.652349	validation_1-merror:0.298909	validation_1-mlogloss:0.661692
# [123]	validation_0-merror:0.294343	validation_0-mlogloss:0.651979	validation_1-merror:0.298794	validation_1-mlogloss:0.661399
# [124]	validation_0-merror:0.294337	validation_0-mlogloss:0.651459	validation_1-merror:0.298436	validation_1-mlogloss:0.660918
# [125]	validation_0-merror:0.294206	validation_0-mlogloss:0.651166	validation_1-merror:0.298436	validation_1-mlogloss:0.660709
# [126]	validation_0-merror:0.293679	validation_0-mlogloss:0.650724	validation_1-merror:0.298359	validation_1-mlogloss:0.660373
# [127]	validation_0-merror:0.293394	validation_0-mlogloss:0.650494	validation_1-merror:0.297962	validation_1-mlogloss:0.660218
# [128]	validation_0-merror:0.293224	validation_0-mlogloss:0.650194	validation_1-merror:0.297809	validation_1-mlogloss:0.659999
# [129]	validation_0-merror:0.293005	validation_0-mlogloss:0.649878	validation_1-merror:0.297502	validation_1-mlogloss:0.659782
# [130]	validation_0-merror:0.292397	validation_0-mlogloss:0.649213	validation_1-merror:0.296901	validation_1-mlogloss:0.659152
# [131]	validation_0-merror:0.292199	validation_0-mlogloss:0.648873	validation_1-merror:0.296747	validation_1-mlogloss:0.658864
# [132]	validation_0-merror:0.291848	validation_0-mlogloss:0.648414	validation_1-merror:0.296466	validation_1-mlogloss:0.65842
# [133]	validation_0-merror:0.291503	validation_0-mlogloss:0.648074	validation_1-merror:0.296082	validation_1-mlogloss:0.658124
# [134]	validation_0-merror:0.291514	validation_0-mlogloss:0.647824	validation_1-merror:0.295993	validation_1-mlogloss:0.657961
# [135]	validation_0-merror:0.29135	validation_0-mlogloss:0.647534	validation_1-merror:0.295954	validation_1-mlogloss:0.657755
# [136]	validation_0-merror:0.291136	validation_0-mlogloss:0.647214	validation_1-merror:0.296031	validation_1-mlogloss:0.657496
# [137]	validation_0-merror:0.290873	validation_0-mlogloss:0.64678	validation_1-merror:0.295865	validation_1-mlogloss:0.657174
# [138]	validation_0-merror:0.290686	validation_0-mlogloss:0.64636	validation_1-merror:0.295711	validation_1-mlogloss:0.656889
# [139]	validation_0-merror:0.290615	validation_0-mlogloss:0.646123	validation_1-merror:0.295814	validation_1-mlogloss:0.65673
# [140]	validation_0-merror:0.290368	validation_0-mlogloss:0.645881	validation_1-merror:0.295737	validation_1-mlogloss:0.656558
# [141]	validation_0-merror:0.289765	validation_0-mlogloss:0.645498	validation_1-merror:0.295161	validation_1-mlogloss:0.656238
# [142]	validation_0-merror:0.289595	validation_0-mlogloss:0.645109	validation_1-merror:0.294969	validation_1-mlogloss:0.655929
# [143]	validation_0-merror:0.289683	validation_0-mlogloss:0.644927	validation_1-merror:0.295187	validation_1-mlogloss:0.655777
# [144]	validation_0-merror:0.289524	validation_0-mlogloss:0.64461	validation_1-merror:0.294982	validation_1-mlogloss:0.655536
# [145]	validation_0-merror:0.289349	validation_0-mlogloss:0.644348	validation_1-merror:0.29465	validation_1-mlogloss:0.655309
# [146]	validation_0-merror:0.289129	validation_0-mlogloss:0.644147	validation_1-merror:0.294752	validation_1-mlogloss:0.655165
# [147]	validation_0-merror:0.289014	validation_0-mlogloss:0.643818	validation_1-merror:0.294739	validation_1-mlogloss:0.654867
# [148]	validation_0-merror:0.288833	validation_0-mlogloss:0.643413	validation_1-merror:0.294624	validation_1-mlogloss:0.654488
# [149]	validation_0-merror:0.288724	validation_0-mlogloss:0.64317	validation_1-merror:0.294381	validation_1-mlogloss:0.654269
# [150]	validation_0-merror:0.288603	validation_0-mlogloss:0.642963	validation_1-merror:0.294381	validation_1-mlogloss:0.654144
# [151]	validation_0-merror:0.288159	validation_0-mlogloss:0.642611	validation_1-merror:0.294151	validation_1-mlogloss:0.653882
# [152]	validation_0-merror:0.288082	validation_0-mlogloss:0.642284	validation_1-merror:0.294151	validation_1-mlogloss:0.653602
# [153]	validation_0-merror:0.288	validation_0-mlogloss:0.642027	validation_1-merror:0.294048	validation_1-mlogloss:0.653367
# [154]	validation_0-merror:0.287896	validation_0-mlogloss:0.641519	validation_1-merror:0.293754	validation_1-mlogloss:0.652943
# [155]	validation_0-merror:0.287792	validation_0-mlogloss:0.641261	validation_1-merror:0.29369	validation_1-mlogloss:0.652746
# [156]	validation_0-merror:0.287677	validation_0-mlogloss:0.640938	validation_1-merror:0.293703	validation_1-mlogloss:0.652489
# [157]	validation_0-merror:0.287458	validation_0-mlogloss:0.64054	validation_1-merror:0.293255	validation_1-mlogloss:0.652147
# [158]	validation_0-merror:0.28726	validation_0-mlogloss:0.640254	validation_1-merror:0.293089	validation_1-mlogloss:0.651931
# [159]	validation_0-merror:0.287216	validation_0-mlogloss:0.639945	validation_1-merror:0.293064	validation_1-mlogloss:0.651702
# [160]	validation_0-merror:0.287085	validation_0-mlogloss:0.639697	validation_1-merror:0.292987	validation_1-mlogloss:0.651545
# [161]	validation_0-merror:0.286838	validation_0-mlogloss:0.639413	validation_1-merror:0.292897	validation_1-mlogloss:0.651333
# [162]	validation_0-merror:0.286641	validation_0-mlogloss:0.638999	validation_1-merror:0.292565	validation_1-mlogloss:0.650994
# [163]	validation_0-merror:0.286509	validation_0-mlogloss:0.638861	validation_1-merror:0.292667	validation_1-mlogloss:0.650904
# [164]	validation_0-merror:0.286328	validation_0-mlogloss:0.638678	validation_1-merror:0.292488	validation_1-mlogloss:0.65079
# [165]	validation_0-merror:0.28595	validation_0-mlogloss:0.638433	validation_1-merror:0.292424	validation_1-mlogloss:0.650629
# [166]	validation_0-merror:0.285802	validation_0-mlogloss:0.638136	validation_1-merror:0.292219	validation_1-mlogloss:0.650397
# [167]	validation_0-merror:0.285692	validation_0-mlogloss:0.637915	validation_1-merror:0.292015	validation_1-mlogloss:0.650222
# [168]	validation_0-merror:0.285522	validation_0-mlogloss:0.637685	validation_1-merror:0.292079	validation_1-mlogloss:0.650067
# [169]	validation_0-merror:0.285446	validation_0-mlogloss:0.637349	validation_1-merror:0.291964	validation_1-mlogloss:0.649755
# [170]	validation_0-merror:0.285457	validation_0-mlogloss:0.63711	validation_1-merror:0.291989	validation_1-mlogloss:0.649583
# [171]	validation_0-merror:0.285331	validation_0-mlogloss:0.636946	validation_1-merror:0.291759	validation_1-mlogloss:0.649466
# [172]	validation_0-merror:0.285067	validation_0-mlogloss:0.636585	validation_1-merror:0.291414	validation_1-mlogloss:0.649197
# [173]	validation_0-merror:0.284826	validation_0-mlogloss:0.636243	validation_1-merror:0.291311	validation_1-mlogloss:0.6489
# [174]	validation_0-merror:0.284788	validation_0-mlogloss:0.636026	validation_1-merror:0.291068	validation_1-mlogloss:0.648754
# [175]	validation_0-merror:0.284618	validation_0-mlogloss:0.635717	validation_1-merror:0.291081	validation_1-mlogloss:0.648548
# [176]	validation_0-merror:0.284223	validation_0-mlogloss:0.635262	validation_1-merror:0.290684	validation_1-mlogloss:0.648121
# [177]	validation_0-merror:0.284042	validation_0-mlogloss:0.635035	validation_1-merror:0.290672	validation_1-mlogloss:0.647959
# [178]	validation_0-merror:0.283987	validation_0-mlogloss:0.634779	validation_1-merror:0.290672	validation_1-mlogloss:0.647759
# [179]	validation_0-merror:0.283785	validation_0-mlogloss:0.63449	validation_1-merror:0.290109	validation_1-mlogloss:0.647554
# [180]	validation_0-merror:0.283187	validation_0-mlogloss:0.6339	validation_1-merror:0.289879	validation_1-mlogloss:0.647
# [181]	validation_0-merror:0.283006	validation_0-mlogloss:0.633645	validation_1-merror:0.289712	validation_1-mlogloss:0.646762
# [182]	validation_0-merror:0.282716	validation_0-mlogloss:0.633356	validation_1-merror:0.289418	validation_1-mlogloss:0.646526
# [183]	validation_0-merror:0.282584	validation_0-mlogloss:0.633001	validation_1-merror:0.289316	validation_1-mlogloss:0.646245
# [184]	validation_0-merror:0.282513	validation_0-mlogloss:0.632723	validation_1-merror:0.289162	validation_1-mlogloss:0.646031
# [185]	validation_0-merror:0.282392	validation_0-mlogloss:0.632492	validation_1-merror:0.289124	validation_1-mlogloss:0.645882
# [186]	validation_0-merror:0.282255	validation_0-mlogloss:0.632234	validation_1-merror:0.288996	validation_1-mlogloss:0.645699
# [187]	validation_0-merror:0.282124	validation_0-mlogloss:0.63196	validation_1-merror:0.288932	validation_1-mlogloss:0.645465
# [188]	validation_0-merror:0.281806	validation_0-mlogloss:0.631598	validation_1-merror:0.288676	validation_1-mlogloss:0.64516
# [189]	validation_0-merror:0.281658	validation_0-mlogloss:0.63123	validation_1-merror:0.288446	validation_1-mlogloss:0.644862
# [190]	validation_0-merror:0.281417	validation_0-mlogloss:0.630821	validation_1-merror:0.288548	validation_1-mlogloss:0.644596
# [191]	validation_0-merror:0.281279	validation_0-mlogloss:0.630535	validation_1-merror:0.288293	validation_1-mlogloss:0.64436
# [192]	validation_0-merror:0.28112	validation_0-mlogloss:0.630327	validation_1-merror:0.288101	validation_1-mlogloss:0.644184
# [193]	validation_0-merror:0.280934	validation_0-mlogloss:0.630031	validation_1-merror:0.287922	validation_1-mlogloss:0.643947
# [194]	validation_0-merror:0.280753	validation_0-mlogloss:0.629702	validation_1-merror:0.287819	validation_1-mlogloss:0.643711
# [195]	validation_0-merror:0.280572	validation_0-mlogloss:0.629483	validation_1-merror:0.287807	validation_1-mlogloss:0.643557
# [196]	validation_0-merror:0.280419	validation_0-mlogloss:0.629333	validation_1-merror:0.28773	validation_1-mlogloss:0.643445
# [197]	validation_0-merror:0.280364	validation_0-mlogloss:0.629083	validation_1-merror:0.287679	validation_1-mlogloss:0.643232
# [198]	validation_0-merror:0.280254	validation_0-mlogloss:0.628844	validation_1-merror:0.287627	validation_1-mlogloss:0.643081
# [199]	validation_0-merror:0.280041	validation_0-mlogloss:0.628661	validation_1-merror:0.287589	validation_1-mlogloss:0.642967
# [200]	validation_0-merror:0.279931	validation_0-mlogloss:0.628495	validation_1-merror:0.287461	validation_1-mlogloss:0.642889
# [201]	validation_0-merror:0.279772	validation_0-mlogloss:0.628056	validation_1-merror:0.287295	validation_1-mlogloss:0.642528
# [202]	validation_0-merror:0.279651	validation_0-mlogloss:0.627747	validation_1-merror:0.286898	validation_1-mlogloss:0.642257
# [203]	validation_0-merror:0.279509	validation_0-mlogloss:0.627431	validation_1-merror:0.286822	validation_1-mlogloss:0.641992
# [204]	validation_0-merror:0.279492	validation_0-mlogloss:0.627257	validation_1-merror:0.286681	validation_1-mlogloss:0.641844
# [205]	validation_0-merror:0.27912	validation_0-mlogloss:0.626908	validation_1-merror:0.286425	validation_1-mlogloss:0.641581
# [206]	validation_0-merror:0.278824	validation_0-mlogloss:0.62669	validation_1-merror:0.286297	validation_1-mlogloss:0.641418
# [207]	validation_0-merror:0.27873	validation_0-mlogloss:0.626376	validation_1-merror:0.285773	validation_1-mlogloss:0.641198
# [208]	validation_0-merror:0.27873	validation_0-mlogloss:0.626074	validation_1-merror:0.285977	validation_1-mlogloss:0.640932
# [209]	validation_0-merror:0.278818	validation_0-mlogloss:0.62594	validation_1-merror:0.285875	validation_1-mlogloss:0.640857
# [210]	validation_0-merror:0.278747	validation_0-mlogloss:0.625734	validation_1-merror:0.285747	validation_1-mlogloss:0.640728
# [211]	validation_0-merror:0.278604	validation_0-mlogloss:0.625514	validation_1-merror:0.285709	validation_1-mlogloss:0.640579
# [212]	validation_0-merror:0.278369	validation_0-mlogloss:0.625208	validation_1-merror:0.28553	validation_1-mlogloss:0.640332
# [213]	validation_0-merror:0.278116	validation_0-mlogloss:0.624888	validation_1-merror:0.285606	validation_1-mlogloss:0.640052
# [214]	validation_0-merror:0.277974	validation_0-mlogloss:0.624662	validation_1-merror:0.285555	validation_1-mlogloss:0.63989
# [215]	validation_0-merror:0.277864	validation_0-mlogloss:0.624442	validation_1-merror:0.285555	validation_1-mlogloss:0.63978
# [216]	validation_0-merror:0.277809	validation_0-mlogloss:0.624089	validation_1-merror:0.285543	validation_1-mlogloss:0.639486
# [217]	validation_0-merror:0.277689	validation_0-mlogloss:0.62386	validation_1-merror:0.285453	validation_1-mlogloss:0.639321
# [218]	validation_0-merror:0.277612	validation_0-mlogloss:0.623589	validation_1-merror:0.285363	validation_1-mlogloss:0.639108
# [219]	validation_0-merror:0.277453	validation_0-mlogloss:0.623384	validation_1-merror:0.28521	validation_1-mlogloss:0.638989
# [220]	validation_0-merror:0.277453	validation_0-mlogloss:0.623247	validation_1-merror:0.285172	validation_1-mlogloss:0.638885
# [221]	validation_0-merror:0.277398	validation_0-mlogloss:0.62313	validation_1-merror:0.285133	validation_1-mlogloss:0.638797
# [222]	validation_0-merror:0.27725	validation_0-mlogloss:0.622827	validation_1-merror:0.285108	validation_1-mlogloss:0.638546
# [223]	validation_0-merror:0.277206	validation_0-mlogloss:0.622616	validation_1-merror:0.284993	validation_1-mlogloss:0.638422
# [224]	validation_0-merror:0.276993	validation_0-mlogloss:0.622412	validation_1-merror:0.284634	validation_1-mlogloss:0.638299
# [225]	validation_0-merror:0.27679	validation_0-mlogloss:0.622095	validation_1-merror:0.284545	validation_1-mlogloss:0.638039
# [226]	validation_0-merror:0.276505	validation_0-mlogloss:0.6218	validation_1-merror:0.284379	validation_1-mlogloss:0.63782
# [227]	validation_0-merror:0.276401	validation_0-mlogloss:0.621626	validation_1-merror:0.284263	validation_1-mlogloss:0.637717
# [228]	validation_0-merror:0.276165	validation_0-mlogloss:0.621345	validation_1-merror:0.284097	validation_1-mlogloss:0.637483
# [229]	validation_0-merror:0.276159	validation_0-mlogloss:0.621097	validation_1-merror:0.284033	validation_1-mlogloss:0.63731
# [230]	validation_0-merror:0.276044	validation_0-mlogloss:0.62081	validation_1-merror:0.284123	validation_1-mlogloss:0.637115
# [231]	validation_0-merror:0.275946	validation_0-mlogloss:0.620524	validation_1-merror:0.284046	validation_1-mlogloss:0.636875
# [232]	validation_0-merror:0.275984	validation_0-mlogloss:0.620341	validation_1-merror:0.284008	validation_1-mlogloss:0.636739
# [233]	validation_0-merror:0.275776	validation_0-mlogloss:0.620007	validation_1-merror:0.283931	validation_1-mlogloss:0.63645
# [234]	validation_0-merror:0.275655	validation_0-mlogloss:0.61974	validation_1-merror:0.283905	validation_1-mlogloss:0.636223
# [235]	validation_0-merror:0.275606	validation_0-mlogloss:0.61949	validation_1-merror:0.283841	validation_1-mlogloss:0.63603
# [236]	validation_0-merror:0.275386	validation_0-mlogloss:0.619209	validation_1-merror:0.283675	validation_1-mlogloss:0.635783
# [237]	validation_0-merror:0.275403	validation_0-mlogloss:0.618986	validation_1-merror:0.283726	validation_1-mlogloss:0.635635
# [238]	validation_0-merror:0.275326	validation_0-mlogloss:0.618769	validation_1-merror:0.283522	validation_1-mlogloss:0.635484
# [239]	validation_0-merror:0.275299	validation_0-mlogloss:0.618619	validation_1-merror:0.283343	validation_1-mlogloss:0.635394
# [240]	validation_0-merror:0.275008	validation_0-mlogloss:0.618341	validation_1-merror:0.283163	validation_1-mlogloss:0.635191
# [241]	validation_0-merror:0.274822	validation_0-mlogloss:0.618124	validation_1-merror:0.283074	validation_1-mlogloss:0.635028
# [242]	validation_0-merror:0.274608	validation_0-mlogloss:0.61786	validation_1-merror:0.28301	validation_1-mlogloss:0.634836
# [243]	validation_0-merror:0.274542	validation_0-mlogloss:0.617646	validation_1-merror:0.283036	validation_1-mlogloss:0.634648
# [244]	validation_0-merror:0.274285	validation_0-mlogloss:0.617406	validation_1-merror:0.283036	validation_1-mlogloss:0.634493
# [245]	validation_0-merror:0.27417	validation_0-mlogloss:0.617206	validation_1-merror:0.282869	validation_1-mlogloss:0.634368
# [246]	validation_0-merror:0.274148	validation_0-mlogloss:0.617097	validation_1-merror:0.282818	validation_1-mlogloss:0.634299
# [247]	validation_0-merror:0.273972	validation_0-mlogloss:0.616836	validation_1-merror:0.282626	validation_1-mlogloss:0.6341
# [248]	validation_0-merror:0.273879	validation_0-mlogloss:0.616532	validation_1-merror:0.282665	validation_1-mlogloss:0.633882
# [249]	validation_0-merror:0.273835	validation_0-mlogloss:0.616357	validation_1-merror:0.282588	validation_1-mlogloss:0.633769
# [250]	validation_0-merror:0.273605	validation_0-mlogloss:0.616171	validation_1-merror:0.282422	validation_1-mlogloss:0.63366
# [251]	validation_0-merror:0.273495	validation_0-mlogloss:0.615881	validation_1-merror:0.282242	validation_1-mlogloss:0.633421
# [252]	validation_0-merror:0.273391	validation_0-mlogloss:0.615725	validation_1-merror:0.282255	validation_1-mlogloss:0.633322
# [253]	validation_0-merror:0.273331	validation_0-mlogloss:0.615491	validation_1-merror:0.282179	validation_1-mlogloss:0.633132
# [254]	validation_0-merror:0.273199	validation_0-mlogloss:0.615334	validation_1-merror:0.282051	validation_1-mlogloss:0.633033
# [255]	validation_0-merror:0.273133	validation_0-mlogloss:0.615173	validation_1-merror:0.282076	validation_1-mlogloss:0.632919
# [256]	validation_0-merror:0.27304	validation_0-mlogloss:0.615054	validation_1-merror:0.282089	validation_1-mlogloss:0.632855
# [257]	validation_0-merror:0.272898	validation_0-mlogloss:0.614806	validation_1-merror:0.282179	validation_1-mlogloss:0.632677
# [258]	validation_0-merror:0.272837	validation_0-mlogloss:0.614605	validation_1-merror:0.281769	validation_1-mlogloss:0.632565
# [259]	validation_0-merror:0.272892	validation_0-mlogloss:0.614464	validation_1-merror:0.281577	validation_1-mlogloss:0.63246
# [260]	validation_0-merror:0.272794	validation_0-mlogloss:0.61437	validation_1-merror:0.28159	validation_1-mlogloss:0.632402
# [261]	validation_0-merror:0.272832	validation_0-mlogloss:0.614164	validation_1-merror:0.281462	validation_1-mlogloss:0.632249
# [262]	validation_0-merror:0.272799	validation_0-mlogloss:0.61395	validation_1-merror:0.281475	validation_1-mlogloss:0.632106
# [263]	validation_0-merror:0.272684	validation_0-mlogloss:0.613783	validation_1-merror:0.281411	validation_1-mlogloss:0.632
# [264]	validation_0-merror:0.272525	validation_0-mlogloss:0.61358	validation_1-merror:0.28136	validation_1-mlogloss:0.631886
# [265]	validation_0-merror:0.272344	validation_0-mlogloss:0.613357	validation_1-merror:0.281411	validation_1-mlogloss:0.631726
# [266]	validation_0-merror:0.272306	validation_0-mlogloss:0.613206	validation_1-merror:0.28136	validation_1-mlogloss:0.631634
# [267]	validation_0-merror:0.272202	validation_0-mlogloss:0.613033	validation_1-merror:0.281398	validation_1-mlogloss:0.631514
# [268]	validation_0-merror:0.272021	validation_0-mlogloss:0.612882	validation_1-merror:0.281283	validation_1-mlogloss:0.631437
# [269]	validation_0-merror:0.271922	validation_0-mlogloss:0.612582	validation_1-merror:0.28113	validation_1-mlogloss:0.631191
# [270]	validation_0-merror:0.271752	validation_0-mlogloss:0.612322	validation_1-merror:0.280861	validation_1-mlogloss:0.63098
# [271]	validation_0-merror:0.271725	validation_0-mlogloss:0.612165	validation_1-merror:0.280836	validation_1-mlogloss:0.630886
# [272]	validation_0-merror:0.271571	validation_0-mlogloss:0.61201	validation_1-merror:0.280836	validation_1-mlogloss:0.630761
# [273]	validation_0-merror:0.271538	validation_0-mlogloss:0.611806	validation_1-merror:0.280823	validation_1-mlogloss:0.630656
# [274]	validation_0-merror:0.27139	validation_0-mlogloss:0.611601	validation_1-merror:0.280618	validation_1-mlogloss:0.63049
# [275]	validation_0-merror:0.271154	validation_0-mlogloss:0.611363	validation_1-merror:0.280477	validation_1-mlogloss:0.630292
# [276]	validation_0-merror:0.271061	validation_0-mlogloss:0.611208	validation_1-merror:0.280413	validation_1-mlogloss:0.63018
# [277]	validation_0-merror:0.270974	validation_0-mlogloss:0.610959	validation_1-merror:0.280222	validation_1-mlogloss:0.630029
# [278]	validation_0-merror:0.270902	validation_0-mlogloss:0.610695	validation_1-merror:0.280234	validation_1-mlogloss:0.629785
# [279]	validation_0-merror:0.270776	validation_0-mlogloss:0.610455	validation_1-merror:0.280285	validation_1-mlogloss:0.629589
# [280]	validation_0-merror:0.270672	validation_0-mlogloss:0.610258	validation_1-merror:0.28003	validation_1-mlogloss:0.629462
# [281]	validation_0-merror:0.27059	validation_0-mlogloss:0.610054	validation_1-merror:0.280145	validation_1-mlogloss:0.629292
# [282]	validation_0-merror:0.270475	validation_0-mlogloss:0.609786	validation_1-merror:0.280055	validation_1-mlogloss:0.629099
# [283]	validation_0-merror:0.270425	validation_0-mlogloss:0.609546	validation_1-merror:0.280119	validation_1-mlogloss:0.628933
# [284]	validation_0-merror:0.270255	validation_0-mlogloss:0.609414	validation_1-merror:0.280042	validation_1-mlogloss:0.628848
# [285]	validation_0-merror:0.270201	validation_0-mlogloss:0.609309	validation_1-merror:0.280209	validation_1-mlogloss:0.628786
# [286]	validation_0-merror:0.270014	validation_0-mlogloss:0.609017	validation_1-merror:0.279889	validation_1-mlogloss:0.628534
# [287]	validation_0-merror:0.269965	validation_0-mlogloss:0.608888	validation_1-merror:0.279838	validation_1-mlogloss:0.628464
# [288]	validation_0-merror:0.270009	validation_0-mlogloss:0.608617	validation_1-merror:0.279787	validation_1-mlogloss:0.628249
# [289]	validation_0-merror:0.269866	validation_0-mlogloss:0.608494	validation_1-merror:0.279697	validation_1-mlogloss:0.628175
# [290]	validation_0-merror:0.269784	validation_0-mlogloss:0.608327	validation_1-merror:0.279595	validation_1-mlogloss:0.628064
# [291]	validation_0-merror:0.269581	validation_0-mlogloss:0.608077	validation_1-merror:0.279403	validation_1-mlogloss:0.627867
# [292]	validation_0-merror:0.269477	validation_0-mlogloss:0.607863	validation_1-merror:0.279032	validation_1-mlogloss:0.627684
# [293]	validation_0-merror:0.269433	validation_0-mlogloss:0.607757	validation_1-merror:0.279185	validation_1-mlogloss:0.627635
# [294]	validation_0-merror:0.269307	validation_0-mlogloss:0.607485	validation_1-merror:0.279134	validation_1-mlogloss:0.627425
# [295]	validation_0-merror:0.269269	validation_0-mlogloss:0.607305	validation_1-merror:0.278904	validation_1-mlogloss:0.627309
# [296]	validation_0-merror:0.269071	validation_0-mlogloss:0.607068	validation_1-merror:0.278853	validation_1-mlogloss:0.627128
# [297]	validation_0-merror:0.268984	validation_0-mlogloss:0.606833	validation_1-merror:0.278994	validation_1-mlogloss:0.626949
# [298]	validation_0-merror:0.268836	validation_0-mlogloss:0.60673	validation_1-merror:0.278904	validation_1-mlogloss:0.626898
# [299]	validation_0-merror:0.268781	validation_0-mlogloss:0.606503	validation_1-merror:0.278699	validation_1-mlogloss:0.626706
# [300]	validation_0-merror:0.268682	validation_0-mlogloss:0.606343	validation_1-merror:0.278623	validation_1-mlogloss:0.626571
# [301]	validation_0-merror:0.268649	validation_0-mlogloss:0.606218	validation_1-merror:0.278879	validation_1-mlogloss:0.626519
# [302]	validation_0-merror:0.268627	validation_0-mlogloss:0.606071	validation_1-merror:0.27884	validation_1-mlogloss:0.626408
# [303]	validation_0-merror:0.268479	validation_0-mlogloss:0.605864	validation_1-merror:0.278674	validation_1-mlogloss:0.626263
# [304]	validation_0-merror:0.268457	validation_0-mlogloss:0.60571	validation_1-merror:0.278559	validation_1-mlogloss:0.626162
# [305]	validation_0-merror:0.268364	validation_0-mlogloss:0.605593	validation_1-merror:0.278405	validation_1-mlogloss:0.62608
# [306]	validation_0-merror:0.268326	validation_0-mlogloss:0.605454	validation_1-merror:0.278418	validation_1-mlogloss:0.626006
# [307]	validation_0-merror:0.26832	validation_0-mlogloss:0.605331	validation_1-merror:0.27838	validation_1-mlogloss:0.62595
# [308]	validation_0-merror:0.268123	validation_0-mlogloss:0.605071	validation_1-merror:0.278188	validation_1-mlogloss:0.62573
# [309]	validation_0-merror:0.268096	validation_0-mlogloss:0.604933	validation_1-merror:0.278188	validation_1-mlogloss:0.625648
# [310]	validation_0-merror:0.268024	validation_0-mlogloss:0.604767	validation_1-merror:0.278124	validation_1-mlogloss:0.625535
# [311]	validation_0-merror:0.267822	validation_0-mlogloss:0.604531	validation_1-merror:0.27806	validation_1-mlogloss:0.625355
# [312]	validation_0-merror:0.267794	validation_0-mlogloss:0.604415	validation_1-merror:0.278085	validation_1-mlogloss:0.625268
# [313]	validation_0-merror:0.26763	validation_0-mlogloss:0.604228	validation_1-merror:0.277868	validation_1-mlogloss:0.625167
# [314]	validation_0-merror:0.267361	validation_0-mlogloss:0.603959	validation_1-merror:0.277663	validation_1-mlogloss:0.624916
# [315]	validation_0-merror:0.26735	validation_0-mlogloss:0.603824	validation_1-merror:0.277587	validation_1-mlogloss:0.624816
# [316]	validation_0-merror:0.267229	validation_0-mlogloss:0.603639	validation_1-merror:0.277535	validation_1-mlogloss:0.624694
# [317]	validation_0-merror:0.267169	validation_0-mlogloss:0.603501	validation_1-merror:0.277689	validation_1-mlogloss:0.62462
# [318]	validation_0-merror:0.26712	validation_0-mlogloss:0.603352	validation_1-merror:0.277651	validation_1-mlogloss:0.624523
# [319]	validation_0-merror:0.267016	validation_0-mlogloss:0.603148	validation_1-merror:0.277369	validation_1-mlogloss:0.62435
# [320]	validation_0-merror:0.266868	validation_0-mlogloss:0.602935	validation_1-merror:0.277267	validation_1-mlogloss:0.624177
# [321]	validation_0-merror:0.266791	validation_0-mlogloss:0.602803	validation_1-merror:0.277331	validation_1-mlogloss:0.624095
# [322]	validation_0-merror:0.266753	validation_0-mlogloss:0.602664	validation_1-merror:0.277344	validation_1-mlogloss:0.624
# [323]	validation_0-merror:0.266561	validation_0-mlogloss:0.602439	validation_1-merror:0.277446	validation_1-mlogloss:0.623858
# [324]	validation_0-merror:0.266462	validation_0-mlogloss:0.60229	validation_1-merror:0.277369	validation_1-mlogloss:0.62374
# [325]	validation_0-merror:0.266396	validation_0-mlogloss:0.602085	validation_1-merror:0.277037	validation_1-mlogloss:0.623578
# [326]	validation_0-merror:0.266254	validation_0-mlogloss:0.601924	validation_1-merror:0.276998	validation_1-mlogloss:0.623485
# [327]	validation_0-merror:0.266106	validation_0-mlogloss:0.601786	validation_1-merror:0.276768	validation_1-mlogloss:0.62339
# [328]	validation_0-merror:0.265958	validation_0-mlogloss:0.601569	validation_1-merror:0.276589	validation_1-mlogloss:0.623228
# [329]	validation_0-merror:0.26593	validation_0-mlogloss:0.60143	validation_1-merror:0.276691	validation_1-mlogloss:0.623128
# [330]	validation_0-merror:0.265771	validation_0-mlogloss:0.601266	validation_1-merror:0.276589	validation_1-mlogloss:0.62304
# [331]	validation_0-merror:0.265656	validation_0-mlogloss:0.601099	validation_1-merror:0.276602	validation_1-mlogloss:0.62293
# [332]	validation_0-merror:0.265541	validation_0-mlogloss:0.600847	validation_1-merror:0.276525	validation_1-mlogloss:0.62273
# [333]	validation_0-merror:0.265552	validation_0-mlogloss:0.600696	validation_1-merror:0.276372	validation_1-mlogloss:0.62265
# [334]	validation_0-merror:0.265552	validation_0-mlogloss:0.600557	validation_1-merror:0.27632	validation_1-mlogloss:0.622546
# [335]	validation_0-merror:0.265481	validation_0-mlogloss:0.600385	validation_1-merror:0.276308	validation_1-mlogloss:0.622431
# [336]	validation_0-merror:0.265415	validation_0-mlogloss:0.600197	validation_1-merror:0.276244	validation_1-mlogloss:0.622306
# [337]	validation_0-merror:0.265311	validation_0-mlogloss:0.60005	validation_1-merror:0.276282	validation_1-mlogloss:0.622204
# [338]	validation_0-merror:0.265256	validation_0-mlogloss:0.599898	validation_1-merror:0.276154	validation_1-mlogloss:0.622111
# [339]	validation_0-merror:0.265103	validation_0-mlogloss:0.599614	validation_1-merror:0.275924	validation_1-mlogloss:0.621869
# [340]	validation_0-merror:0.264889	validation_0-mlogloss:0.599432	validation_1-merror:0.275796	validation_1-mlogloss:0.621713
# [341]	validation_0-merror:0.264944	validation_0-mlogloss:0.599215	validation_1-merror:0.275732	validation_1-mlogloss:0.621562
# [342]	validation_0-merror:0.264856	validation_0-mlogloss:0.599074	validation_1-merror:0.275681	validation_1-mlogloss:0.621481
# [343]	validation_0-merror:0.264845	validation_0-mlogloss:0.598888	validation_1-merror:0.275706	validation_1-mlogloss:0.621328
# [344]	validation_0-merror:0.264763	validation_0-mlogloss:0.598775	validation_1-merror:0.275655	validation_1-mlogloss:0.621278
# [345]	validation_0-merror:0.264675	validation_0-mlogloss:0.598589	validation_1-merror:0.275604	validation_1-mlogloss:0.621168
# [346]	validation_0-merror:0.264527	validation_0-mlogloss:0.598457	validation_1-merror:0.275617	validation_1-mlogloss:0.621085
# [347]	validation_0-merror:0.264478	validation_0-mlogloss:0.598335	validation_1-merror:0.275578	validation_1-mlogloss:0.621023
# [348]	validation_0-merror:0.26439	validation_0-mlogloss:0.598107	validation_1-merror:0.275412	validation_1-mlogloss:0.620866
# [349]	validation_0-merror:0.26433	validation_0-mlogloss:0.597939	validation_1-merror:0.275502	validation_1-mlogloss:0.620749
# [350]	validation_0-merror:0.264236	validation_0-mlogloss:0.597799	validation_1-merror:0.275361	validation_1-mlogloss:0.620667
# [351]	validation_0-merror:0.264231	validation_0-mlogloss:0.597657	validation_1-merror:0.275246	validation_1-mlogloss:0.620572
# [352]	validation_0-merror:0.264088	validation_0-mlogloss:0.597478	validation_1-merror:0.275271	validation_1-mlogloss:0.620451
# [353]	validation_0-merror:0.264006	validation_0-mlogloss:0.597393	validation_1-merror:0.275323	validation_1-mlogloss:0.620416
# [354]	validation_0-merror:0.263781	validation_0-mlogloss:0.597112	validation_1-merror:0.275144	validation_1-mlogloss:0.620179
# [355]	validation_0-merror:0.263677	validation_0-mlogloss:0.597003	validation_1-merror:0.275016	validation_1-mlogloss:0.620104
# [356]	validation_0-merror:0.263611	validation_0-mlogloss:0.596871	validation_1-merror:0.275028	validation_1-mlogloss:0.620053
# [357]	validation_0-merror:0.263431	validation_0-mlogloss:0.596645	validation_1-merror:0.274837	validation_1-mlogloss:0.619925
# [358]	validation_0-merror:0.263348	validation_0-mlogloss:0.596473	validation_1-merror:0.274939	validation_1-mlogloss:0.6198
# [359]	validation_0-merror:0.263255	validation_0-mlogloss:0.596266	validation_1-merror:0.274849	validation_1-mlogloss:0.619661
# [360]	validation_0-merror:0.263178	validation_0-mlogloss:0.596028	validation_1-merror:0.27476	validation_1-mlogloss:0.619469
# [361]	validation_0-merror:0.263173	validation_0-mlogloss:0.595942	validation_1-merror:0.274747	validation_1-mlogloss:0.619411
# [362]	validation_0-merror:0.263118	validation_0-mlogloss:0.59578	validation_1-merror:0.274696	validation_1-mlogloss:0.619307
# [363]	validation_0-merror:0.26308	validation_0-mlogloss:0.595667	validation_1-merror:0.27453	validation_1-mlogloss:0.61925
# [364]	validation_0-merror:0.263041	validation_0-mlogloss:0.595438	validation_1-merror:0.274287	validation_1-mlogloss:0.619063
# [365]	validation_0-merror:0.262976	validation_0-mlogloss:0.595307	validation_1-merror:0.274351	validation_1-mlogloss:0.61898
# [366]	validation_0-merror:0.262943	validation_0-mlogloss:0.595185	validation_1-merror:0.274325	validation_1-mlogloss:0.618911
# [367]	validation_0-merror:0.262871	validation_0-mlogloss:0.595066	validation_1-merror:0.274312	validation_1-mlogloss:0.618831
# [368]	validation_0-merror:0.262778	validation_0-mlogloss:0.594942	validation_1-merror:0.274274	validation_1-mlogloss:0.618746
# [369]	validation_0-merror:0.26268	validation_0-mlogloss:0.594765	validation_1-merror:0.274235	validation_1-mlogloss:0.61862
# [370]	validation_0-merror:0.26269	validation_0-mlogloss:0.594552	validation_1-merror:0.274376	validation_1-mlogloss:0.618503
# [371]	validation_0-merror:0.262433	validation_0-mlogloss:0.594359	validation_1-merror:0.274351	validation_1-mlogloss:0.618377
# [372]	validation_0-merror:0.262422	validation_0-mlogloss:0.594235	validation_1-merror:0.27421	validation_1-mlogloss:0.618297
# [373]	validation_0-merror:0.262334	validation_0-mlogloss:0.594072	validation_1-merror:0.274363	validation_1-mlogloss:0.618178
# [374]	validation_0-merror:0.262175	validation_0-mlogloss:0.593851	validation_1-merror:0.27412	validation_1-mlogloss:0.618029
# [375]	validation_0-merror:0.262153	validation_0-mlogloss:0.593721	validation_1-merror:0.274069	validation_1-mlogloss:0.617959
# [376]	validation_0-merror:0.262071	validation_0-mlogloss:0.59357	validation_1-merror:0.27398	validation_1-mlogloss:0.617843
# [377]	validation_0-merror:0.261939	validation_0-mlogloss:0.593386	validation_1-merror:0.273865	validation_1-mlogloss:0.617706
# [378]	validation_0-merror:0.261874	validation_0-mlogloss:0.593248	validation_1-merror:0.273826	validation_1-mlogloss:0.61761
# [379]	validation_0-merror:0.261682	validation_0-mlogloss:0.593059	validation_1-merror:0.273839	validation_1-mlogloss:0.617474
# [380]	validation_0-merror:0.261594	validation_0-mlogloss:0.592926	validation_1-merror:0.273749	validation_1-mlogloss:0.617404
# [381]	validation_0-merror:0.261446	validation_0-mlogloss:0.592774	validation_1-merror:0.273506	validation_1-mlogloss:0.617304
# ...
# [877]	validation_0-merror:0.235539	validation_0-mlogloss:0.54207	validation_1-merror:0.260626	validation_1-mlogloss:0.590692
# [878]	validation_0-merror:0.235528	validation_0-mlogloss:0.541981	validation_1-merror:0.260652	validation_1-mlogloss:0.590658
# [879]	validation_0-merror:0.235402	validation_0-mlogloss:0.541917	validation_1-merror:0.260588	validation_1-mlogloss:0.590632
# [880]	validation_0-merror:0.235314	validation_0-mlogloss:0.541857	validation_1-merror:0.260511	validation_1-mlogloss:0.590618
# [881]	validation_0-merror:0.235237	validation_0-mlogloss:0.541792	validation_1-merror:0.260524	validation_1-mlogloss:0.590605
# [882]	validation_0-merror:0.23538	validation_0-mlogloss:0.541702	validation_1-merror:0.260485	validation_1-mlogloss:0.590574
# [883]	validation_0-merror:0.235429	validation_0-mlogloss:0.541626	validation_1-merror:0.260485	validation_1-mlogloss:0.590541
# [884]	validation_0-merror:0.235347	validation_0-mlogloss:0.541538	validation_1-merror:0.260396	validation_1-mlogloss:0.590479
# [885]	validation_0-merror:0.235358	validation_0-mlogloss:0.541448	validation_1-merror:0.260396	validation_1-mlogloss:0.590443
# [886]	validation_0-merror:0.235314	validation_0-mlogloss:0.541379	validation_1-merror:0.260447	validation_1-mlogloss:0.590398
# [887]	validation_0-merror:0.235314	validation_0-mlogloss:0.541281	validation_1-merror:0.260524	validation_1-mlogloss:0.590354
# [888]	validation_0-merror:0.235177	validation_0-mlogloss:0.541183	validation_1-merror:0.260473	validation_1-mlogloss:0.590316
# [889]	validation_0-merror:0.235111	validation_0-mlogloss:0.541096	validation_1-merror:0.260485	validation_1-mlogloss:0.590271
# [890]	validation_0-merror:0.235056	validation_0-mlogloss:0.541022	validation_1-merror:0.260434	validation_1-mlogloss:0.590234
# [891]	validation_0-merror:0.234974	validation_0-mlogloss:0.540966	validation_1-merror:0.260524	validation_1-mlogloss:0.590223
# [892]	validation_0-merror:0.234958	validation_0-mlogloss:0.54089	validation_1-merror:0.260562	validation_1-mlogloss:0.590187
# [893]	validation_0-merror:0.234985	validation_0-mlogloss:0.540815	validation_1-merror:0.260562	validation_1-mlogloss:0.590172
# [894]	validation_0-merror:0.234974	validation_0-mlogloss:0.54073	validation_1-merror:0.260498	validation_1-mlogloss:0.590116
# [895]	validation_0-merror:0.23498	validation_0-mlogloss:0.540671	validation_1-merror:0.260498	validation_1-mlogloss:0.590114
# [896]	validation_0-merror:0.234963	validation_0-mlogloss:0.540605	validation_1-merror:0.260575	validation_1-mlogloss:0.590109
# [897]	validation_0-merror:0.234936	validation_0-mlogloss:0.540535	validation_1-merror:0.260716	validation_1-mlogloss:0.590088
# [898]	validation_0-merror:0.234859	validation_0-mlogloss:0.54044	validation_1-merror:0.260703	validation_1-mlogloss:0.590046
# [899]	validation_0-merror:0.234788	validation_0-mlogloss:0.540358	validation_1-merror:0.26069	validation_1-mlogloss:0.590028
# [900]	validation_0-merror:0.234832	validation_0-mlogloss:0.540297	validation_1-merror:0.260677	validation_1-mlogloss:0.590015
# [901]	validation_0-merror:0.234854	validation_0-mlogloss:0.540241	validation_1-merror:0.260652	validation_1-mlogloss:0.589994
# [902]	validation_0-merror:0.23481	validation_0-mlogloss:0.540183	validation_1-merror:0.260511	validation_1-mlogloss:0.589979
# [903]	validation_0-merror:0.234766	validation_0-mlogloss:0.540111	validation_1-merror:0.260536	validation_1-mlogloss:0.58995
# [904]	validation_0-merror:0.234766	validation_0-mlogloss:0.540049	validation_1-merror:0.260447	validation_1-mlogloss:0.589923
# [905]	validation_0-merror:0.234744	validation_0-mlogloss:0.539981	validation_1-merror:0.260447	validation_1-mlogloss:0.589897
# [906]	validation_0-merror:0.234695	validation_0-mlogloss:0.539908	validation_1-merror:0.260536	validation_1-mlogloss:0.589869
# [907]	validation_0-merror:0.234728	validation_0-mlogloss:0.539838	validation_1-merror:0.260409	validation_1-mlogloss:0.589841
# [908]	validation_0-merror:0.23464	validation_0-mlogloss:0.539772	validation_1-merror:0.260473	validation_1-mlogloss:0.589826
# [909]	validation_0-merror:0.234547	validation_0-mlogloss:0.539713	validation_1-merror:0.260562	validation_1-mlogloss:0.589797
# [910]	validation_0-merror:0.234541	validation_0-mlogloss:0.539632	validation_1-merror:0.260562	validation_1-mlogloss:0.589748
# [911]	validation_0-merror:0.234481	validation_0-mlogloss:0.539546	validation_1-merror:0.260549	validation_1-mlogloss:0.589708
# [912]	validation_0-merror:0.234536	validation_0-mlogloss:0.539469	validation_1-merror:0.260703	validation_1-mlogloss:0.589683
# [913]	validation_0-merror:0.234448	validation_0-mlogloss:0.539367	validation_1-merror:0.260447	validation_1-mlogloss:0.589636
# [914]	validation_0-merror:0.234426	validation_0-mlogloss:0.539319	validation_1-merror:0.260447	validation_1-mlogloss:0.589623
# [915]	validation_0-merror:0.234393	validation_0-mlogloss:0.539232	validation_1-merror:0.260383	validation_1-mlogloss:0.589579
# [916]	validation_0-merror:0.234393	validation_0-mlogloss:0.539167	validation_1-merror:0.260396	validation_1-mlogloss:0.589548
# [917]	validation_0-merror:0.234256	validation_0-mlogloss:0.539095	validation_1-merror:0.260357	validation_1-mlogloss:0.589532
# [918]	validation_0-merror:0.23424	validation_0-mlogloss:0.539031	validation_1-merror:0.260345	validation_1-mlogloss:0.589505
# [919]	validation_0-merror:0.234146	validation_0-mlogloss:0.538958	validation_1-merror:0.26037	validation_1-mlogloss:0.589475
# [920]	validation_0-merror:0.23407	validation_0-mlogloss:0.538861	validation_1-merror:0.260498	validation_1-mlogloss:0.589445
# [921]	validation_0-merror:0.23396	validation_0-mlogloss:0.538795	validation_1-merror:0.26046	validation_1-mlogloss:0.589419
# [922]	validation_0-merror:0.233911	validation_0-mlogloss:0.538738	validation_1-merror:0.260549	validation_1-mlogloss:0.589414
# [923]	validation_0-merror:0.233872	validation_0-mlogloss:0.538674	validation_1-merror:0.260639	validation_1-mlogloss:0.589392
# [924]	validation_0-merror:0.233807	validation_0-mlogloss:0.5386	validation_1-merror:0.260562	validation_1-mlogloss:0.589366
# [925]	validation_0-merror:0.233796	validation_0-mlogloss:0.538552	validation_1-merror:0.2606	validation_1-mlogloss:0.589364
# [926]	validation_0-merror:0.233768	validation_0-mlogloss:0.53845	validation_1-merror:0.2606	validation_1-mlogloss:0.589333
# [927]	validation_0-merror:0.233757	validation_0-mlogloss:0.53839	validation_1-merror:0.260511	validation_1-mlogloss:0.589316
# [928]	validation_0-merror:0.23362	validation_0-mlogloss:0.538313	validation_1-merror:0.260485	validation_1-mlogloss:0.58929
# [929]	validation_0-merror:0.233615	validation_0-mlogloss:0.538261	validation_1-merror:0.260473	validation_1-mlogloss:0.589282
# [930]	validation_0-merror:0.233582	validation_0-mlogloss:0.538178	validation_1-merror:0.260498	validation_1-mlogloss:0.589255
# [931]	validation_0-merror:0.233511	validation_0-mlogloss:0.538099	validation_1-merror:0.260447	validation_1-mlogloss:0.589235
# [932]	validation_0-merror:0.2335	validation_0-mlogloss:0.538016	validation_1-merror:0.260409	validation_1-mlogloss:0.58919
# [933]	validation_0-merror:0.233472	validation_0-mlogloss:0.537958	validation_1-merror:0.26037	validation_1-mlogloss:0.589175
# [934]	validation_0-merror:0.233434	validation_0-mlogloss:0.537868	validation_1-merror:0.260293	validation_1-mlogloss:0.589133
# [935]	validation_0-merror:0.233379	validation_0-mlogloss:0.537786	validation_1-merror:0.260217	validation_1-mlogloss:0.589088
# [936]	validation_0-merror:0.233368	validation_0-mlogloss:0.537734	validation_1-merror:0.260178	validation_1-mlogloss:0.589072
# [937]	validation_0-merror:0.233379	validation_0-mlogloss:0.537669	validation_1-merror:0.260268	validation_1-mlogloss:0.589072
# [938]	validation_0-merror:0.233374	validation_0-mlogloss:0.53761	validation_1-merror:0.260204	validation_1-mlogloss:0.589037
# [939]	validation_0-merror:0.233335	validation_0-mlogloss:0.53755	validation_1-merror:0.26014	validation_1-mlogloss:0.589015
# [940]	validation_0-merror:0.233291	validation_0-mlogloss:0.537503	validation_1-merror:0.260217	validation_1-mlogloss:0.589005
# [941]	validation_0-merror:0.233204	validation_0-mlogloss:0.53743	validation_1-merror:0.260306	validation_1-mlogloss:0.588989
# [942]	validation_0-merror:0.233078	validation_0-mlogloss:0.537365	validation_1-merror:0.260178	validation_1-mlogloss:0.588972
# [943]	validation_0-merror:0.233078	validation_0-mlogloss:0.537298	validation_1-merror:0.26014	validation_1-mlogloss:0.588951
# [944]	validation_0-merror:0.233088	validation_0-mlogloss:0.537241	validation_1-merror:0.260166	validation_1-mlogloss:0.588932
# [945]	validation_0-merror:0.233099	validation_0-mlogloss:0.537147	validation_1-merror:0.260076	validation_1-mlogloss:0.588888
# [946]	validation_0-merror:0.233045	validation_0-mlogloss:0.537071	validation_1-merror:0.260089	validation_1-mlogloss:0.588868
# [947]	validation_0-merror:0.233034	validation_0-mlogloss:0.537003	validation_1-merror:0.260114	validation_1-mlogloss:0.588846
# [948]	validation_0-merror:0.233061	validation_0-mlogloss:0.536913	validation_1-merror:0.260063	validation_1-mlogloss:0.588809
# [949]	validation_0-merror:0.232935	validation_0-mlogloss:0.536818	validation_1-merror:0.259961	validation_1-mlogloss:0.588776
# [950]	validation_0-merror:0.232919	validation_0-mlogloss:0.536759	validation_1-merror:0.259961	validation_1-mlogloss:0.58876
# [951]	validation_0-merror:0.232847	validation_0-mlogloss:0.536712	validation_1-merror:0.260012	validation_1-mlogloss:0.588739
# [952]	validation_0-merror:0.232825	validation_0-mlogloss:0.536651	validation_1-merror:0.260063	validation_1-mlogloss:0.588738
# [953]	validation_0-merror:0.232847	validation_0-mlogloss:0.536592	validation_1-merror:0.26005	validation_1-mlogloss:0.588715
# [954]	validation_0-merror:0.232787	validation_0-mlogloss:0.536508	validation_1-merror:0.260012	validation_1-mlogloss:0.588674
# [955]	validation_0-merror:0.232809	validation_0-mlogloss:0.536471	validation_1-merror:0.259948	validation_1-mlogloss:0.588669
# [956]	validation_0-merror:0.232721	validation_0-mlogloss:0.536375	validation_1-merror:0.259948	validation_1-mlogloss:0.588608
# [957]	validation_0-merror:0.232749	validation_0-mlogloss:0.536319	validation_1-merror:0.260012	validation_1-mlogloss:0.588582
# [958]	validation_0-merror:0.232754	validation_0-mlogloss:0.536226	validation_1-merror:0.259961	validation_1-mlogloss:0.588543
# [959]	validation_0-merror:0.232705	validation_0-mlogloss:0.53615	validation_1-merror:0.259846	validation_1-mlogloss:0.588521
# [960]	validation_0-merror:0.232672	validation_0-mlogloss:0.536068	validation_1-merror:0.259884	validation_1-mlogloss:0.588503
# [961]	validation_0-merror:0.232644	validation_0-mlogloss:0.536005	validation_1-merror:0.25991	validation_1-mlogloss:0.588466
# [962]	validation_0-merror:0.232568	validation_0-mlogloss:0.535936	validation_1-merror:0.25991	validation_1-mlogloss:0.588436
# [963]	validation_0-merror:0.23259	validation_0-mlogloss:0.535883	validation_1-merror:0.259935	validation_1-mlogloss:0.58842
# [964]	validation_0-merror:0.23248	validation_0-mlogloss:0.53582	validation_1-merror:0.25991	validation_1-mlogloss:0.588404
# [965]	validation_0-merror:0.232414	validation_0-mlogloss:0.535756	validation_1-merror:0.25991	validation_1-mlogloss:0.588382
# [966]	validation_0-merror:0.232376	validation_0-mlogloss:0.535698	validation_1-merror:0.259948	validation_1-mlogloss:0.58837
# [967]	validation_0-merror:0.232321	validation_0-mlogloss:0.535612	validation_1-merror:0.259986	validation_1-mlogloss:0.588332
# [968]	validation_0-merror:0.232272	validation_0-mlogloss:0.535514	validation_1-merror:0.259961	validation_1-mlogloss:0.588271
# [969]	validation_0-merror:0.232222	validation_0-mlogloss:0.535452	validation_1-merror:0.259935	validation_1-mlogloss:0.588251
# [970]	validation_0-merror:0.23225	validation_0-mlogloss:0.535372	validation_1-merror:0.259948	validation_1-mlogloss:0.588216
# [971]	validation_0-merror:0.232217	validation_0-mlogloss:0.535298	validation_1-merror:0.259922	validation_1-mlogloss:0.588197
# [972]	validation_0-merror:0.232222	validation_0-mlogloss:0.535241	validation_1-merror:0.259948	validation_1-mlogloss:0.588174
# [973]	validation_0-merror:0.23214	validation_0-mlogloss:0.535179	validation_1-merror:0.259922	validation_1-mlogloss:0.588153
# [974]	validation_0-merror:0.232157	validation_0-mlogloss:0.53513	validation_1-merror:0.259961	validation_1-mlogloss:0.588135
# [975]	validation_0-merror:0.232173	validation_0-mlogloss:0.535057	validation_1-merror:0.259948	validation_1-mlogloss:0.588092
# [976]	validation_0-merror:0.232217	validation_0-mlogloss:0.534998	validation_1-merror:0.259897	validation_1-mlogloss:0.588076
# [977]	validation_0-merror:0.232146	validation_0-mlogloss:0.534952	validation_1-merror:0.259871	validation_1-mlogloss:0.588065
# [978]	validation_0-merror:0.232096	validation_0-mlogloss:0.534889	validation_1-merror:0.259871	validation_1-mlogloss:0.588034
# [979]	validation_0-merror:0.23214	validation_0-mlogloss:0.534832	validation_1-merror:0.259846	validation_1-mlogloss:0.588027
# [980]	validation_0-merror:0.232085	validation_0-mlogloss:0.534764	validation_1-merror:0.259897	validation_1-mlogloss:0.587996
# [981]	validation_0-merror:0.232052	validation_0-mlogloss:0.534672	validation_1-merror:0.259833	validation_1-mlogloss:0.587946
# [982]	validation_0-merror:0.232069	validation_0-mlogloss:0.534606	validation_1-merror:0.259795	validation_1-mlogloss:0.587926
# [983]	validation_0-merror:0.231976	validation_0-mlogloss:0.534523	validation_1-merror:0.259807	validation_1-mlogloss:0.587903
# [984]	validation_0-merror:0.231987	validation_0-mlogloss:0.534467	validation_1-merror:0.259782	validation_1-mlogloss:0.587873
# [985]	validation_0-merror:0.231959	validation_0-mlogloss:0.534396	validation_1-merror:0.259743	validation_1-mlogloss:0.587828
# [986]	validation_0-merror:0.231926	validation_0-mlogloss:0.534323	validation_1-merror:0.259743	validation_1-mlogloss:0.587783
# [987]	validation_0-merror:0.231888	validation_0-mlogloss:0.534239	validation_1-merror:0.259692	validation_1-mlogloss:0.587753
# [988]	validation_0-merror:0.231872	validation_0-mlogloss:0.534154	validation_1-merror:0.259743	validation_1-mlogloss:0.587731
# [989]	validation_0-merror:0.231773	validation_0-mlogloss:0.534098	validation_1-merror:0.259807	validation_1-mlogloss:0.587736
# [990]	validation_0-merror:0.231833	validation_0-mlogloss:0.534016	validation_1-merror:0.259782	validation_1-mlogloss:0.587699
# [991]	validation_0-merror:0.231839	validation_0-mlogloss:0.533943	validation_1-merror:0.259795	validation_1-mlogloss:0.587656
# [992]	validation_0-merror:0.231762	validation_0-mlogloss:0.533883	validation_1-merror:0.259846	validation_1-mlogloss:0.58763
# [993]	validation_0-merror:0.231702	validation_0-mlogloss:0.533823	validation_1-merror:0.259859	validation_1-mlogloss:0.587597
# [994]	validation_0-merror:0.231614	validation_0-mlogloss:0.533733	validation_1-merror:0.259795	validation_1-mlogloss:0.587544
# [995]	validation_0-merror:0.231603	validation_0-mlogloss:0.533666	validation_1-merror:0.259756	validation_1-mlogloss:0.587535
# [996]	validation_0-merror:0.231619	validation_0-mlogloss:0.533598	validation_1-merror:0.259628	validation_1-mlogloss:0.587511
# [997]	validation_0-merror:0.231652	validation_0-mlogloss:0.53355	validation_1-merror:0.259564	validation_1-mlogloss:0.587487
# [998]	validation_0-merror:0.231586	validation_0-mlogloss:0.533462	validation_1-merror:0.259692	validation_1-mlogloss:0.587448
# [999]	validation_0-merror:0.231559	validation_0-mlogloss:0.533418	validation_1-merror:0.259718	validation_1-mlogloss:0.587438
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=4, num_class=3, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=42, silent=None, subsample=0.8, verbosity=1)

# %%
y_pred = xgb.predict(x_test)

# %%
# get results
results = xgb.evals_result()
epochs = len(results['validation_0']['merror'])
x_axis = range(epochs)

# %%
# plot merror
plt.plot(x_axis, results['validation_0']['merror'], label='train')
plt.plot(x_axis, results['validation_1']['merror'], label='test')
plt.xlabel('Epoch')
plt.ylabel('Merror')
plt.title('Multiclas Classification Error Rate')
plt.legend();

# %%
# plot mlogloss
plt.plot(x_axis, results['validation_0']['mlogloss'], label='train')
plt.plot(x_axis, results['validation_1']['mlogloss'], label='test')
plt.xlabel('Epoch')
plt.ylabel('mlogloss')
plt.title('Multiclass Logloss')
plt.legend();

# %%
confusion_matrix(y_test, y_pred, labels=[1,2,3])
# Out:
# array([[ 3792,  3720,    89],
#        [ 1453, 37987,  4974],
#        [  127,  9942, 16097]])

# %%
plot_confusion_matrix(xgb, x_test, y_test, normalize='true');

# %%
f1_score(y_test, y_pred, average='micro')
# Out:
# 0.740282165743595

# %%
cross_val_score(xgb, x_train, y_train, cv=3).mean()
# Out:
# 0.7366133128732432

# %% [markdown]
# f1_score: 0.74\
# cross_val_score: 0.7366

# %% [markdown]
# #### Explaination with SHAP

# %%
import shap

# %%
explainer = shap.TreeExplainer(xgb)

# %%
shap_values = explainer.shap_values(x_test.iloc[:1000,:])

# %%
shap.initjs()
shap.summary_plot(shap_values, x_test.iloc[:1000,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# SHAP calculates the probabilities on the log-odds space: $log(p) = log\frac{p}{(1-p)}$\
# The features in pink increase the log-odds probability, whereas the features in blue decrease it, in the proportion of each feature bar length.\
# The first two predictions are shown ahead:

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[0], shap_values[0][0,:], x_test.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iOXO489RZ6NPBN67H3DVG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.8251999616622925, "outValue": -2.879276752471924, "link": "identity", "featureNames": ["geo_level_3_id", "geo_level_2_id", "geo_level_1_id", "age", "area_percentage", "height_percentage", "count_families", "count_floors_pre_eq", "foundation_type_r", "has_superstructure_mud_mortar_stone", "has_superstructure_timber", "land_surface_condition_t", "has_superstructure_cement_mortar_brick", "ground_floor_type_f", "land_surface_condition_n", "position_s", "has_superstructure_adobe_mud", "other_floor_type_q", "roof_type_n", "position_t", "roof_type_q", "has_superstructure_bamboo", "foundation_type_i", "has_superstructure_mud_mortar_brick", "other_floor_type_x", "ground_floor_type_x", "has_superstructure_stone_flag", "geo1_kmeans"], "features": {"0": {"effect": 0.03067733719944954, "value": 11128.0}, "1": {"effect": -0.30053451657295227, "value": 1224.0}, "2": {"effect": -0.8110026717185974, "value": 10.0}, "3": {"effect": -0.3707957863807678, "value": 20.0}, "4": {"effect": -0.028560835868120193, "value": 7.0}, "5": {"effect": 0.12607236206531525, "value": 3.0}, "6": {"effect": -0.05491005256772041, "value": 1.0}, "7": {"effect": 0.022487932816147804, "value": 1.0}, "8": {"effect": -0.15051330626010895, "value": 1.0}, "9": {"effect": -0.3860831558704376, "value": 1.0}, "10": {"effect": -0.03387148305773735, "value": 0.0}, "11": {"effect": 0.031717125326395035, "value": 1.0}, "12": {"effect": 0.002900635590776801, "value": 0.0}, "13": {"effect": -0.12305125594139099, "value": 1.0}, "14": {"effect": -0.010526362806558609, "value": 0.0}, "15": {"effect": -0.010666381567716599, "value": 1.0}, "16": {"effect": 0.01423377264291048, "value": 0.0}, "17": {"effect": 0.03884631395339966, "value": 0.0}, "18": {"effect": -0.06028610095381737, "value": 1.0}, "19": {"effect": 0.01115366443991661, "value": 0.0}, "20": {"effect": 0.02572467550635338, "value": 0.0}, "21": {"effect": -0.01033386867493391, "value": 0.0}, "22": {"effect": -0.012457339093089104, "value": 0.0}, "23": {"effect": 0.000804760551545769, "value": 0.0}, "24": {"effect": 0.0223685372620821, "value": 0.0}, "25": {"effect": 0.020867494866251945, "value": 0.0}, "26": {"effect": 0.01853407919406891, "value": 0.0}, "27": {"effect": -0.05687221512198448, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOXO489RZ6NPBN67H3DVG')
#   );
# </script>

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1][0,:], x_test.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iOPOMSAPN1D0ABWLQ5BWZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 1.193399429321289, "outValue": 0.7974131107330322, "link": "identity", "featureNames": ["geo_level_3_id", "geo_level_2_id", "geo_level_1_id", "age", "area_percentage", "height_percentage", "count_families", "count_floors_pre_eq", "foundation_type_r", "has_superstructure_mud_mortar_stone", "has_superstructure_timber", "land_surface_condition_t", "has_superstructure_cement_mortar_brick", "ground_floor_type_f", "land_surface_condition_n", "position_s", "has_superstructure_adobe_mud", "other_floor_type_q", "roof_type_n", "position_t", "roof_type_q", "has_superstructure_bamboo", "foundation_type_i", "has_superstructure_mud_mortar_brick", "other_floor_type_x", "ground_floor_type_x", "has_superstructure_stone_flag", "geo1_kmeans"], "features": {"0": {"effect": -0.16876937448978424, "value": 11128.0}, "1": {"effect": -0.031177397817373276, "value": 1224.0}, "2": {"effect": 0.07068334519863129, "value": 10.0}, "3": {"effect": 0.018928296864032745, "value": 20.0}, "4": {"effect": 0.011653450317680836, "value": 7.0}, "5": {"effect": -0.014216532930731773, "value": 3.0}, "6": {"effect": -0.0042245774529874325, "value": 1.0}, "7": {"effect": -0.03819657862186432, "value": 1.0}, "8": {"effect": -0.0003586395760066807, "value": 1.0}, "9": {"effect": 0.005534256808459759, "value": 1.0}, "10": {"effect": -0.01905221678316593, "value": 0.0}, "11": {"effect": 0.0027695943135768175, "value": 1.0}, "12": {"effect": -0.030860424041748047, "value": 0.0}, "13": {"effect": -0.00039445204311050475, "value": 1.0}, "14": {"effect": -0.01257591973990202, "value": 0.0}, "15": {"effect": -0.028653739020228386, "value": 1.0}, "16": {"effect": -0.011502999812364578, "value": 0.0}, "17": {"effect": -0.11845716089010239, "value": 0.0}, "18": {"effect": -0.003864467376843095, "value": 1.0}, "19": {"effect": 0.004402925260365009, "value": 0.0}, "20": {"effect": -0.0004298509447835386, "value": 0.0}, "21": {"effect": -0.0003363077703397721, "value": 0.0}, "22": {"effect": 0.0043035345152020454, "value": 0.0}, "23": {"effect": -0.025081036612391472, "value": 0.0}, "24": {"effect": -0.006633075885474682, "value": 0.0}, "25": {"effect": 0.005653186235576868, "value": 0.0}, "26": {"effect": 0.003291928907856345, "value": 0.0}, "27": {"effect": -0.008422077633440495, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOPOMSAPN1D0ABWLQ5BWZ')
#   );
# </script>

# %% [markdown]
# # Submission

# %%
val_df.shape
# Out:
# (86868, 28)

# %%
ids = val['building_id']

# %%
pred_submission = xgb.predict(val_df)

# %%
submission = pd.DataFrame(pred_submission, index=ids, columns=['damage_grade'])

# %%
submission.head()
# Out:
#              damage_grade
# building_id
# 300051                  3
# 99355                   2
# 890251                  2
# 745817                  1
# 421793                  3

# %%
submission.to_csv('/content/drive/My Drive/Colab Notebooks/Competições/Modeling Earthquake Damage/submission.csv')

# %% [markdown]
# # Save and Load Model

# %%
import pickle

# %%
# save the model
pickle.dump(xgb, open('xgboost_model.sv','wb'))

# %%
# load the model
load_xgb = pickle.load(open('xgboost_model.sv','rb'))
